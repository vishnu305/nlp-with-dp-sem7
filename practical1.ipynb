# %%
# Read in the data and clean up column names
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)
messages = pd.read_csv('supportTicketData.csv')
# messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["text", "label"]
messages.head()
# Out:
#                                                                                                   text  \
# 0  connection issues with assigned address hi facing connection issues number en tried changing cab...
# 1  cannot access hi cannot access fallowing link get blank cannot proceed can you please help with ...
# 2  re address shown valid dear colleagues remarked name written wrong could you please be change th...
# 3  sent tuesday critical alert following alert occurred status active data source type data source ...
# 4               code spelling mistake hello should discover for code please can you change thanks head
#
#   label
# 0    P1
# 1    P2
# 2    P1
# 3    P2
# 4    P2

# %%
messages = messages[messages['label']!='P3']

# %%
# Clean data using the built in cleaner in gensim
messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
messages.head()
# Out:
#                                                                                                   text  \
# 0  connection issues with assigned address hi facing connection issues number en tried changing cab...
# 1  cannot access hi cannot access fallowing link get blank cannot proceed can you please help with ...
# 2  re address shown valid dear colleagues remarked name written wrong could you please be change th...
# 3  sent tuesday critical alert following alert occurred status active data source type data source ...
# 4               code spelling mistake hello should discover for code please can you change thanks head
#
#   label  \
# 0    P1
# 1    P2
# 2    P1
# 3    P2
# 4    P2
#
#                                                                                             text_clean
# 0  [connection, issues, with, assigned, address, hi, facing, connection, issues, number, en, tried,...
# 1  [cannot, access, hi, cannot, access, fallowing, link, get, blank, cannot, proceed, can, you, ple...
# 2  [re, address, shown, valid, dear, colleagues, remarked, name, written, wrong, could, you, please...
# 3  [sent, tuesday, critical, alert, following, alert, occurred, status, active, data, source, type,...
# 4  [code, spelling, mistake, hello, should, discover, for, code, please, can, you, change, thanks, ...

# %%
np.unique(messages['label'])
# Out:
# array(['P1', 'P2'], dtype=object)

# %%
# Encoding the label column
messages['label']=messages['label'].map({'P1':1,'P2':2})
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split (messages['text_clean'], messages['label'] , test_size=0.2)

# %%
# Train the word2vec model
w2v_model = gensim.models.Word2Vec(X_train,
                                   vector_size=100,
                                   window=5,
                                   min_count=2)

# %%
w2v_model.wv.index_to_key
# Out:
# ['you',
#  'for',
#  'please',
#  'sent',
#  'have',
#  'with',
#  'can',
#  'hi',
#  'regards',
#  'be',
#  'hello',
#  'thank',
#  'error',
#  'we',
#  'thanks',
#  'your',
#  'access',
#  're',
#  'issue',
#  'could',
#  'if',
#  'manager',
#  'but',
#  'or',
#  'help',
#  'when',
#  'below',
#  'en',
#  'any',
#  'kind',
#  'was',
#  'monday',
#  'tuesday',
#  'there',
#  'best',
#  'need',
#  'issues',
#  'wednesday',
#  'cannot',
#  'friday',
#  'one',
#  'by',
#  'thursday',
#  'problem',
#  'ticket',
#  'log',
#  'message',
#  'dear',
#  'should',
#  'approval',
#  'request',
#  'submit',
#  'some',
#  'engineer',
#  'know',
#  'leave',
#  'card',
#  'working',
#  'following',
#  'details',
#  'th',
#  'ext',
#  'october',
#  'check',
#  'get',
#  'senior',
#  'also',
#  'attached',
#  'our',
#  'days',
#  'laptop',
#  'report',
#  'november',
#  'let',
#  'date',
#  'information',
#  'password',
#  'sa',
#  'able',
#  'july',
#  'change',
#  'update',
#  'analyst',
#  'open',
#  'work',
#  'action',
#  'trying',
#  'week',
#  'after',
#  'high',
#  'more',
#  'still',
#  'up',
#  'server',
#  'only',
#  'tried',
#  'contact',
#  'client',
#  'task',
#  'into',
#  'status',
#  'using',
#  'what',
#  'out',
#  'hours',
#  'submitted',
#  'would',
#  'number',
#  'data',
#  'advise',
#  'december',
#  'unable',
#  'assigned',
#  'try',
#  'same',
#  'upgrade',
#  'because',
#  'annual',
#  'code',
#  'si',
#  'importance',
#  'again',
#  'use',
#  'cards',
#  'them',
#  'received',
#  'add',
#  'last',
#  'find',
#  'look',
#  'address',
#  'february',
#  'failed',
#  'approve',
#  'screen',
#  'these',
#  'today',
#  'connection',
#  'la',
#  'developer',
#  'march',
#  'connect',
#  'officer',
#  'investigate',
#  'like',
#  'id',
#  'how',
#  'delete',
#  'name',
#  'required',
#  'other',
#  'phone',
#  'line',
#  'seems',
#  'does',
#  'why',
#  'his',
#  'incident',
#  'view',
#  'expense',
#  'reports',
#  'possible',
#  'updates',
#  'about',
#  'had',
#  'approved',
#  'link',
#  'order',
#  'take',
#  'here',
#  'available',
#  'floor',
#  'raise',
#  'note',
#  'guys',
#  'entered',
#  'make',
#  'receive',
#  'notification',
#  'then',
#  'process',
#  'enter',
#  'fix',
#  'list',
#  'hub',
#  'period',
#  'ca',
#  'tester',
#  'since',
#  'timecard',
#  'application',
#  'set',
#  'problems',
#  'start',
#  'advised',
#  'back',
#  'assign',
#  'each',
#  'software',
#  'having',
#  'lead',
#  'getting',
#  'call',
#  'click',
#  'assist',
#  'her',
#  'already',
#  'disk',
#  'were',
#  'very',
#  'administrator',
#  'further',
#  'location',
#  'she',
#  'receiving',
#  'file',
#  'another',
#  'applications',
#  'correct',
#  'however',
#  'entries',
#  'meeting',
#  'provide',
#  'alert',
#  'active',
#  'resolved',
#  'next',
#  'well',
#  'through',
#  'head',
#  'logged',
#  'case',
#  'while',
#  'colleagues',
#  'currently',
#  'before',
#  'mobile',
#  'review',
#  'type',
#  'job',
#  'regarding',
#  'morning',
#  'computer',
#  'test',
#  'being',
#  'site',
#  'send',
#  'found',
#  'did',
#  'urgent',
#  'got',
#  'old',
#  'description',
#  'errors',
#  'created',
#  'files',
#  'care',
#  'end',
#  'down',
#  'via',
#  'current',
#  'changed',
#  'something',
#  'assistance',
#  'credentials',
#  'under',
#  'lost',
#  'kindly',
#  'infrastructure',
#  'updated',
#  'due',
#  'even',
#  'per',
#  'two',
#  'appears',
#  'their',
#  'mailbox',
#  'space',
#  'st',
#  'info',
#  'actions',
#  'contract',
#  'someone',
#  'go',
#  'requests',
#  'consultant',
#  'main',
#  'added',
#  'documents',
#  'anything',
#  'rejected',
#  'fusion',
#  'off',
#  'used',
#  'se',
#  'related',
#  'original',
#  'cost',
#  'part',
#  'create',
#  'holiday',
#  'full',
#  'few',
#  'direct',
#  'needed',
#  'absence',
#  'users',
#  'priority',
#  'might',
#  'form',
#  'option',
#  'than',
#  'much',
#  'resolve',
#  'right',
#  'entry',
#  'over',
#  'free',
#  'accounts',
#  'folder',
#  'complete',
#  'event',
#  'projects',
#  'connected',
#  'above',
#  'longer',
#  'comments',
#  'mon',
#  'changes',
#  'total',
#  'button',
#  'ask',
#  'logging',
#  'restart',
#  'print',
#  'managed',
#  'room',
#  'good',
#  'side',
#  'done',
#  'va',
#  'every',
#  'wrong',
#  'think',
#  'document',
#  'past',
#  'additional',
#  'image',
#  'needs',
#  'app',
#  'device',
#  'run',
#  'version',
#  'sheet',
#  'without',
#  'started',
#  'source',
#  'person',
#  'ad',
#  'reset',
#  'yesterday',
#  'certificate',
#  'customer',
#  'count',
#  'drive',
#  'noticed',
#  'times',
#  'works',
#  'install',
#  'select',
#  'web',
#  'checked',
#  'rights',
#  'want',
#  'cable',
#  'specialist',
#  'printer',
#  'domain',
#  'feedback',
#  'remote',
#  'keep',
#  'during',
#  'until',
#  'confluence',
#  'accordingly',
#  'fixed',
#  'close',
#  'resolution',
#  'appear',
#  'left',
#  'asap',
#  'response',
#  'those',
#  'where',
#  'tickets',
#  'intended',
#  'haven',
#  'machine',
#  'seem',
#  'country',
#  'attachments',
#  'submission',
#  'step',
#  'really',
#  'way',
#  'display',
#  'content',
#  'center',
#  'search',
#  'requisition',
#  'reason',
#  'different',
#  'reference',
#  'occurred',
#  'made',
#  'members',
#  'ago',
#  'registered',
#  'recipient',
#  'anymore',
#  'looks',
#  'deleted',
#  'dec',
#  'taken',
#  'frankfurt',
#  'perform',
#  'solve',
#  'critical',
#  'month',
#  'reported',
#  'weeks',
#  'testing',
#  'accessing',
#  'must',
#  'steps',
#  'clients',
#  'once',
#  'properly',
#  'although',
#  'everyone',
#  'colleague',
#  'matter',
#  'survey',
#  'leaver',
#  'monitoring',
#  'installed',
#  'save',
#  'excel',
#  'confirm',
#  'communication',
#  'key',
#  'teams',
#  'environment',
#  'saved',
#  'pot',
#  'forward',
#  'leader',
#  'closed',
#  'license',
#  'him',
#  'informed',
#  'unfortunately',
#  'warning',
#  'stop',
#  'either',
#  'queue',
#  'looking',
#  'timecards',
#  'belgrade',
#  'shows',
#  'multiple',
#  'several',
#  'apple',
#  'give',
#  'monitor',
#  'visible',
#  'permissions',
#  'shared',
#  'accept',
#  'displayed',
#  'sign',
#  'important',
#  'configuration',
#  'happens',
#  'going',
#  'questions',
#  'tasks',
#  'yet',
#  'area',
#  'field',
#  'upcoming',
#  'pending',
#  'summary',
#  'previous',
#  'calendar',
#  'mob',
#  'requested',
#  'instead',
#  'allow',
#  'regular',
#  'moment',
#  'mentioned',
#  'manage',
#  'remove',
#  'minutes',
#  'showing',
#  'library',
#  'completed',
#  'll',
#  'dc',
#  'tape',
#  'starting',
#  'chrome',
#  'between',
#  'automatically',
#  'running',
#  'such',
#  'weekly',
#  'upload',
#  'po',
#  'lot',
#  'items',
#  'submitting',
#  'second',
#  'item',
#  'locked',
#  'believe',
#  'value',
#  'follow',
#  'gets',
#  'encounter',
#  'confidential',
#  'technical',
#  'solution',
#  'forecast',
#  'raised',
#  'kb',
#  'browser',
#  'solved',
#  'resources',
#  'fine',
#  'desktop',
#  'section',
#  'experiencing',
#  'connecting',
#  'pc',
#  'default',
#  'entity',
#  'blvd',
#  'portal',
#  'yes',
#  'kingdom',
#  'results',
#  'public',
#  'links',
#  'proceed',
#  'owner',
#  'record',
#  'calls',
#  'training',
#  'example',
#  'breakdown',
#  'ref',
#  'rd',
#  'control',
#  'year',
#  'point',
#  'opportunity',
#  'cheers',
#  'correctly',
#  'provided',
#  'sorry',
#  'zone',
#  'menu',
#  'entire',
#  'wed',
#  'employee',
#  'within',
#  'though',
#  'etc',
#  'asking',
#  'too',
#  'everything',
#  'great',
#  'hesitate',
#  'size',
#  'require',
#  'tool',
#  'happened',
#  'basis',
#  'street',
#  'situation',
#  'enough',
#  'daily',
#  'consider',
#  'nothing',
#  'bug',
#  'hold',
#  'setup',
#  'recently',
#  'explorer',
#  'employees',
#  'apply',
#  'query',
#  'contacts',
#  'book',
#  'amount',
#  'wireless',
#  'followed',
#  'personal',
#  'maybe',
#  'snow',
#  'virus',
#  'alarm',
#  'directory',
#  'git',
#  'based',
#  'pipeline',
#  'options',
#  'badge',
#  'door',
#  'console',
#  'level',
#  'msg',
#  'build',
#  'history',
#  'wait',
#  'bad',
#  'release',
#  'assignee',
#  'asked',
#  'established',
#  'codes',
#  'database',
#  'authentication',
#  'encountered',
#  'says',
#  'opinions',
#  'fill',
#  'reminder',
#  'couple',
#  'mine',
#  'understand',
#  'notice',
#  'external',
#  'planning',
#  'slow',
#  'separate',
#  'costs',
#  'verify',
#  'career',
#  'tomorrow',
#  'appreciate',
#  'generated',
#  'experience',
#  'input',
#  'mb',
#  'notified',
#  'profile',
#  'progress',
#  'flow',
#  'sending',
#  'member',
#  'monthly',
#  'accountant',
#  'directly',
#  'notify',
#  'performance',
#  'invoice',
#  'tab',
#  'district',
#  'latest',
#  'starter',
#  'months',
#  'integration',
#  'assets',
#  'setting',
#  'approvals',
#  'discipline',
#  'happening',
#  'conference',
#  'processes',
#  'most',
#  'almost',
#  'writing',
#  'switch',
#  'performed',
#  'bit',
#  'os',
#  'keyboard',
#  'programme',
#  'failure',
#  'doing',
#  'opening',
#  'quality',
#  'groups',
#  'tower',
#  'installation',
#  'empty',
#  'immediately',
#  'settings',
#  'result',
#  'ensure',
#  'devices',
#  'previously',
#  'granted',
#  'around',
#  'tm',
#  'appropriate',
#  'dashboard',
#  'adding',
#  'come',
#  'download',
#  'path',
#  'liability',
#  'vacation',
#  'usually',
#  'least',
#  'enabled',
#  'digital',
#  'necessary',
#  'shown',
#  'put',
#  'manually',
#  'awaiting',
#  'checking',
#  'choose',
#  'understanding',
#  'assignment',
#  'recovery',
#  'broad',
#  'master',
#  'approver',
#  'worked',
#  'entering',
#  'driver',
#  'move',
#  'known',
#  'similar',
#  'incorrect',
#  'broken',
#  'purchase',
#  'ie',
#  'including',
#  'fact',
#  'fields',
#  'meetings',
#  'blocked',
#  'keeps',
#  'non',
#  'share',
#  'wants',
#  'reach',
#  'show',
#  'director',
#  'cause',
#  'none',
#  'totals',
#  'port',
#  'seen',
#  'write',
#  'confirmed',
#  'records',
#  'low',
#  'place',
#  'restarting',
#  'db',
#  'host',
#  'unavailable',
#  'always',
#  'self',
#  'wrote',
#  'sheets',
#  'tell',
#  'special',
#  'assistant',
#  'cr',
#  'saying',
#  'present',
#  'copy',
#  'privileged',
#  'whether',
#  'valid',
#  'compliance',
#  'servers',
#  'join',
#  'myself',
#  'folders',
#  'successfully',
#  'solely',
#  'press',
#  'battery',
#  'bellow',
#  'approvers',
#  'design',
#  'import',
#  'return',
#  'inform',
#  'advice',
#  'overtime',
#  'saturday',
#  'hardware',
#  'thread',
#  'bogota',
#  'weekend',
#  'recent',
#  'win',
#  'normal',
#  'replace',
#  'maternity',
#  'otherwise',
#  'gone',
#  'pass',
#  'hand',
#  'absences',
#  'product',
#  'ones',
#  'extension',
#  'instructions',
#  'merge',
#  'marketing',
#  'resubmit',
#  'expired',
#  'guest',
#  'english',
#  'disabled',
#  'aware',
#  'rooms',
#  'specific',
#  'waiting',
#  'module',
#  'mistake',
#  'export',
#  'window',
#  'supplier',
#  'sometimes',
#  'tools',
#  'caused',
#  'outside',
#  'approving',
#  'copying',
#  'portfolio',
#  'forced',
#  'relevant',
#  'guide',
#  'investigating',
#  'impact',
#  'returned',
#  'stuck',
#  'invalid',
#  'won',
#  'receipt',
#  'schedule',
#  'necessarily',
#  'therefore',
#  'mails',
#  'picture',
#  'idea',
#  'seconds',
#  'ne',
#  'fatal',
#  'memory',
#  'estimated',
#  'machines',
#  'changing',
#  'sat',
#  'attempting',
#  'administration',
#  'moved',
#  'coming',
#  'later',
#  'far',
#  'permission',
#  'treat',
#  'feel',
#  'continue',
#  'reject',
#  'question',
#  'went',
#  'listed',
#  'cpu',
#  'attach',
#  'future',
#  'br',
#  'lines',
#  'sales',
#  'subsidiaries',
#  'sector',
#  'stopped',
#  'policy',
#  'incidents',
#  'companies',
#  'behavior',
#  'blank',
#  'recommended',
#  'represent',
#  'payable',
#  'disclosure',
#  'transfer',
#  'removed',
#  'top',
#  'expected',
#  'hearing',
#  'agent',
#  'single',
#  'marked',
#  'prohibited',
#  'yellow',
#  'offer',
#  'wired',
#  'instance',
#  'protection',
#  'confirmation',
#  'operation',
#  'scheduled',
#  'subject',
#  'architect',
#  'happen',
#  'strictly',
#  'corrective',
#  'unless',
#  'trouble',
#  'probably',
#  'video',
#  'expire',
#  'android',
#  'avoid',
#  'sync',
#  'helped',
#  'face',
#  'causes',
#  'corresponding',
#  'command',
#  'blocking',
#  'drop',
#  'taking',
#  'licenses',
#  'usage',
#  'program',
#  'hour',
#  'icon',
#  'given',
#  'logs',
#  'telephone',
#  'referral',
#  'activate',
#  'contracts',
#  'increase',
#  'operations',
#  'equipment',
#  'prompt',
#  'values',
#  'against',
#  'procedure',
#  'unknown',
#  'takes',
#  'materials',
#  'metric',
#  'updating',
#  'urgently',
#  'reasons',
#  'target',
#  'fixing',
#  'contain',
#  'holidays',
#  'conversation',
#  'nor',
#  'identification',
#  'agile',
#  'lifespan',
#  'tot',
#  'wanted',
#  'session',
#  'reliance',
#  'apparently',
#  'hey',
#  'planned',
#  'false',
#  'tv',
#  'others',
#  'newsletter',
#  'quiz',
#  'controller',
#  'whose',
#  'red',
#  'located',
#  'allowed',
#  'template',
#  'object',
#  'article',
#  'slave',
#  'actual',
#  'selected',
#  'forms',
#  'mode',
#  'hard',
#  'installing',
#  'indicated',
#  'points',
#  'investigation',
#  ...]

# %%
# Find the most similar words to "cabin" based on word vectors from our trained model
w2v_model.wv.most_similar('proceed')
# Out:
# [('how', 0.8494408130645752),
#  ('tell', 0.801354169845581),
#  ('clarify', 0.7923555970191956),
#  ('what', 0.7646125555038452),
#  ('happening', 0.7602647542953491),
#  ('instruct', 0.7393451929092407),
#  ('advise', 0.723324716091156),
#  ('situation', 0.7193887829780579),
#  ('clue', 0.7146585583686829),
#  ('confirm', 0.7126659750938416)]

# %%
words = set(w2v_model.wv.index_to_key )
X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_train])
X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
                         for ls in X_test])
# Out:
# C:\Users\divve\AppData\Local\Temp\ipykernel_8364\22094319.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])
# C:\Users\divve\AppData\Local\Temp\ipykernel_8364\22094319.py:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_test_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in words])

# %% [markdown]
# # Padding

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
X_train_vect_avg = []
for v in X_train_vect:
    if v.size:
        X_train_vect_avg.append(v.mean(axis=0))
    else:
        X_train_vect_avg.append(np.zeros(100, dtype=float))
        
X_test_vect_avg = []
for v in X_test_vect:
    if v.size:
        X_test_vect_avg.append(v.mean(axis=0))
    else:
        X_test_vect_avg.append(np.zeros(100, dtype=float))

# %%
# Instantiate and fit a basic Random Forest model on top of the vectors
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect_avg, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect_avg)

# %%
from sklearn.metrics import precision_score, recall_score
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(round(precision, 3), round(recall, 3), round((y_pred==y_test).sum()/len(y_pred), 3)))
# Out:
# Precision: 0.622 / Recall: 0.757 / Accuracy: 0.618
