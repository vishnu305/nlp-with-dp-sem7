# %%
import numpy as np
import tensorflow as tf

# %%
# Step 2 - Take a Sample text

raw_text = 'He is the king . The king is royal . She is the royal  queen '
raw_text = raw_text.lower()

# %%
# Step 3 - Create Dictionary

My_words = []
for word in raw_text.split():
    if word != '.': 
        My_words.append(word)
My_words = set(My_words) 
My_word2int = {}
My_int2word = {}
vocabulary_size = len(My_words) 
for i,word in enumerate(My_words):
    My_word2int[word] = i

# %%
# Step 4 - Create list of Sentences

# raw sentences is a list of sentences.
raw_text_2 = raw_text.split('.')
sentences = []
for sentence in raw_text_2:
    sentences.append(sentence.split())
print("The list of sentenses is:",sentences)
# Out:
# The list of sentenses is: [['he', 'is', 'the', 'king'], ['the', 'king', 'is', 'royal'], ['she', 'is', 'the', 'royal', 'queen']]

# %%
# Step 5 - Generate training data

king_data = []
Set_window_size = 2
for sentence in sentences:
    for word_index, word in enumerate(sentence):
        for nb_word in sentence[max(word_index - Set_window_size, 0) : min(word_index + Set_window_size, len(sentence)) + 1] : 
            if nb_word != word:
                king_data.append([word, nb_word])
print("The list of word pairs is:",king_data)
# Out:
# The list of word pairs is: [['he', 'is'], ['he', 'the'], ['is', 'he'], ['is', 'the'], ['is', 'king'], ['the', 'he'], ['the', 'is'], ['the', 'king'], ['king', 'is'], ['king', 'the'], ['the', 'king'], ['the', 'is'], ['king', 'the'], ['king', 'is'], ['king', 'royal'], ['is', 'the'], ['is', 'king'], ['is', 'royal'], ['royal', 'king'], ['royal', 'is'], ['she', 'is'], ['she', 'the'], ['is', 'she'], ['is', 'the'], ['is', 'royal'], ['the', 'she'], ['the', 'is'], ['the', 'royal'], ['the', 'queen'], ['royal', 'is'], ['royal', 'the'], ['royal', 'queen'], ['queen', 'the'], ['queen', 'royal']]

# %%
# Step 6 - One hot encoding

def one_hot(index_data_point, vocabulary_size):
    temp = np.zeros(vocabulary_size)
    temp[index_data_point] = 1
    return temp
x_train_data = [] # this is for input word
y_train_data = [] # this is for output word
for word_data in king_data:

    x_train_data.append(one_hot(My_word2int[word_data[0]], vocabulary_size))
    y_train_data.append(one_hot(My_word2int[word_data[1]], vocabulary_size))
# convert them to numpy arrays

# %%
# Step 7 - Shape of train data

print("This is the shape for x_train and y_train:",len(x_train_data), len(y_train_data))
# Out:
# This is the shape for x_train and y_train: 34 34

# %%
# Step 8 - Disable the eagre execution

tf.compat.v1.disable_eager_execution()

# %%
# Step 9 - Make a tensorflow model

x_new = tf.compat.v1.placeholder(tf.float32, shape=(None, vocabulary_size))
label_y = tf.compat.v1.placeholder(tf.float32, shape=(None, vocabulary_size))

# %%
# Step 10 - Convert data into embedded representation

dim_embbed = 5
W1_data = tf.Variable(tf.compat.v1.random_normal([vocabulary_size, dim_embbed]))
b1_data = tf.Variable(tf.compat.v1.random_normal([dim_embbed])) #bias
representation_hidden = tf.add(tf.matmul(x_new,W1_data), b1_data)

# %%
# Step 11 - Make Predictions

W2_data = tf.Variable(tf.compat.v1.random_normal([dim_embbed, vocabulary_size]))
b2_data = tf.Variable(tf.compat.v1.random_normal([vocabulary_size]))
Make_prediction = tf.nn.softmax(tf.add( tf.matmul(representation_hidden, W2_data), b2_data))

# %%
# Step 12 - Train the data

sess = tf.compat.v1.Session()
initialize_var = tf.compat.v1.global_variables_initializer()
sess.run(initialize_var)
# define the loss function:
cross_entropy_loss = tf.reduce_mean(-tf.reduce_sum(label_y * tf.compat.v1.log(Make_prediction), axis=[1]))
# define the training step:
Step_train = tf.compat.v1.train.GradientDescentOptimizer(0.1).minimize(cross_entropy_loss)
iters = 10000
# train for defined iterations
for ele in range(iters):
    sess.run(Step_train, feed_dict={x_new: x_train_data, label_y: y_train_data})
    print('The loss is : ', sess.run(cross_entropy_loss, feed_dict={x_new: x_train_data, label_y: y_train_data}))
# Out:
# The loss is :  3.1886606
# The loss is :  2.9891226
# The loss is :  2.840277
# The loss is :  2.7191966
# The loss is :  2.6169872
# The loss is :  2.5292654
# The loss is :  2.4534187
# The loss is :  2.3876977
# The loss is :  2.3307807
# The loss is :  2.2815254
# The loss is :  2.2388504
# The loss is :  2.2017133
# The loss is :  2.1691418
# The loss is :  2.1402717
# The loss is :  2.1143742
# The loss is :  2.090859
# The loss is :  2.0692627
# The loss is :  2.0492296
# The loss is :  2.03049
# The loss is :  2.01284
# The loss is :  1.996126
# The loss is :  1.9802309
# The loss is :  1.9650632
# The loss is :  1.9505523
# The loss is :  1.9366407
# The loss is :  1.9232824
# The loss is :  1.9104381
# The loss is :  1.8980746
# The loss is :  1.8861638
# The loss is :  1.8746799
# The loss is :  1.8636006
# The loss is :  1.8529055
# The loss is :  1.842576
# The loss is :  1.832595
# The loss is :  1.8229465
# The loss is :  1.8136159
# The loss is :  1.8045892
# The loss is :  1.795853
# The loss is :  1.7873955
# The loss is :  1.7792045
# The loss is :  1.7712694
# The loss is :  1.7635791
# The loss is :  1.7561237
# The loss is :  1.7488939
# The loss is :  1.7418799
# The loss is :  1.7350736
# The loss is :  1.7284663
# The loss is :  1.7220498
# The loss is :  1.715817
# The loss is :  1.7097598
# The loss is :  1.7038718
# The loss is :  1.6981463
# The loss is :  1.6925765
# The loss is :  1.6871566
# The loss is :  1.6818806
# The loss is :  1.676743
# The loss is :  1.6717384
# The loss is :  1.6668618
# The loss is :  1.6621084
# The loss is :  1.6574734
# The loss is :  1.6529527
# The loss is :  1.6485415
# The loss is :  1.6442364
# The loss is :  1.6400334
# The loss is :  1.6359286
# The loss is :  1.6319189
# The loss is :  1.6280009
# The loss is :  1.624171
# The loss is :  1.6204267
# The loss is :  1.6167653
# The loss is :  1.6131833
# The loss is :  1.6096786
# The loss is :  1.606249
# The loss is :  1.6028914
# The loss is :  1.599604
# The loss is :  1.5963845
# The loss is :  1.5932308
# The loss is :  1.590141
# The loss is :  1.5871134
# The loss is :  1.5841455
# The loss is :  1.5812364
# The loss is :  1.5783838
# The loss is :  1.5755863
# The loss is :  1.5728425
# The loss is :  1.5701507
# The loss is :  1.5675095
# The loss is :  1.5649178
# The loss is :  1.5623741
# The loss is :  1.559877
# The loss is :  1.5574257
# The loss is :  1.5550184
# The loss is :  1.5526547
# The loss is :  1.550333
# The loss is :  1.5480523
# The loss is :  1.5458117
# The loss is :  1.5436102
# The loss is :  1.5414467
# The loss is :  1.5393206
# The loss is :  1.5372306
# The loss is :  1.5351763
# The loss is :  1.5331564
# The loss is :  1.5311704
# The loss is :  1.5292174
# The loss is :  1.5272967
# The loss is :  1.5254076
# The loss is :  1.523549
# The loss is :  1.5217206
# The loss is :  1.5199217
# The loss is :  1.5181515
# The loss is :  1.5164095
# The loss is :  1.5146949
# The loss is :  1.5130073
# The loss is :  1.511346
# The loss is :  1.5097103
# The loss is :  1.5080998
# The loss is :  1.5065141
# The loss is :  1.5049523
# The loss is :  1.503414
# The loss is :  1.501899
# The loss is :  1.5004065
# The loss is :  1.498936
# The loss is :  1.4974872
# The loss is :  1.4960597
# The loss is :  1.4946529
# The loss is :  1.4932662
# The loss is :  1.4918996
# The loss is :  1.4905524
# The loss is :  1.4892244
# The loss is :  1.4879148
# The loss is :  1.4866238
# The loss is :  1.4853506
# The loss is :  1.484095
# The loss is :  1.4828565
# The loss is :  1.4816351
# The loss is :  1.4804299
# The loss is :  1.4792411
# The loss is :  1.4780681
# The loss is :  1.4769108
# The loss is :  1.4757686
# The loss is :  1.4746413
# The loss is :  1.4735289
# The loss is :  1.4724308
# The loss is :  1.4713466
# The loss is :  1.4702764
# The loss is :  1.4692197
# The loss is :  1.4681764
# The loss is :  1.4671459
# The loss is :  1.4661283
# The loss is :  1.4651233
# The loss is :  1.4641305
# The loss is :  1.4631499
# The loss is :  1.4621812
# The loss is :  1.4612241
# The loss is :  1.4602783
# The loss is :  1.4593438
# The loss is :  1.4584202
# The loss is :  1.4575074
# The loss is :  1.4566053
# The loss is :  1.4557136
# The loss is :  1.4548321
# The loss is :  1.4539607
# The loss is :  1.4530991
# The loss is :  1.452247
# The loss is :  1.4514047
# The loss is :  1.4505717
# The loss is :  1.4497478
# The loss is :  1.4489329
# The loss is :  1.4481268
# The loss is :  1.4473295
# The loss is :  1.4465406
# The loss is :  1.4457604
# The loss is :  1.4449884
# The loss is :  1.4442244
# The loss is :  1.4434686
# The loss is :  1.4427204
# The loss is :  1.4419802
# The loss is :  1.4412473
# The loss is :  1.4405221
# The loss is :  1.4398043
# The loss is :  1.4390936
# The loss is :  1.43839
# The loss is :  1.4376936
# The loss is :  1.437004
# The loss is :  1.4363211
# The loss is :  1.435645
# The loss is :  1.4349756
# The loss is :  1.4343123
# The loss is :  1.4336556
# The loss is :  1.4330053
# The loss is :  1.4323611
# The loss is :  1.431723
# The loss is :  1.4310907
# The loss is :  1.4304645
# The loss is :  1.429844
# The loss is :  1.4292293
# The loss is :  1.4286203
# The loss is :  1.4280168
# The loss is :  1.4274188
# The loss is :  1.4268262
# The loss is :  1.4262391
# The loss is :  1.4256572
# The loss is :  1.4250804
# The loss is :  1.4245086
# The loss is :  1.4239419
# The loss is :  1.4233803
# The loss is :  1.4228235
# The loss is :  1.4222715
# The loss is :  1.4217244
# The loss is :  1.4211818
# The loss is :  1.4206442
# The loss is :  1.420111
# The loss is :  1.4195821
# The loss is :  1.4190581
# The loss is :  1.4185381
# The loss is :  1.4180228
# The loss is :  1.4175113
# The loss is :  1.4170043
# The loss is :  1.4165016
# The loss is :  1.416003
# The loss is :  1.4155084
# The loss is :  1.4150177
# The loss is :  1.4145312
# The loss is :  1.4140486
# The loss is :  1.4135699
# The loss is :  1.4130949
# The loss is :  1.4126238
# The loss is :  1.4121563
# The loss is :  1.4116926
# The loss is :  1.4112327
# The loss is :  1.4107763
# The loss is :  1.4103234
# The loss is :  1.4098741
# The loss is :  1.4094284
# The loss is :  1.408986
# The loss is :  1.408547
# The loss is :  1.4081112
# The loss is :  1.4076792
# The loss is :  1.4072502
# The loss is :  1.4068245
# The loss is :  1.4064019
# The loss is :  1.4059825
# The loss is :  1.4055665
# The loss is :  1.4051534
# The loss is :  1.4047434
# The loss is :  1.4043365
# The loss is :  1.4039327
# The loss is :  1.4035317
# The loss is :  1.4031339
# The loss is :  1.4027388
# The loss is :  1.4023466
# The loss is :  1.4019575
# The loss is :  1.401571
# The loss is :  1.4011873
# The loss is :  1.4008065
# The loss is :  1.4004284
# The loss is :  1.400053
# The loss is :  1.3996803
# The loss is :  1.3993104
# The loss is :  1.3989428
# The loss is :  1.3985782
# The loss is :  1.3982158
# The loss is :  1.3978564
# The loss is :  1.3974992
# The loss is :  1.3971446
# The loss is :  1.3967924
# The loss is :  1.3964428
# The loss is :  1.3960956
# The loss is :  1.3957509
# The loss is :  1.3954083
# The loss is :  1.3950683
# The loss is :  1.3947306
# The loss is :  1.3943952
# The loss is :  1.3940623
# The loss is :  1.3937312
# The loss is :  1.3934028
# The loss is :  1.3930767
# The loss is :  1.3927525
# The loss is :  1.3924305
# The loss is :  1.3921107
# The loss is :  1.3917933
# The loss is :  1.3914777
# The loss is :  1.3911644
# The loss is :  1.3908532
# The loss is :  1.3905439
# The loss is :  1.390237
# The loss is :  1.3899318
# The loss is :  1.3896289
# The loss is :  1.3893276
# The loss is :  1.3890287
# The loss is :  1.3887317
# The loss is :  1.3884366
# The loss is :  1.3881433
# The loss is :  1.3878521
# The loss is :  1.3875626
# The loss is :  1.3872751
# The loss is :  1.3869895
# The loss is :  1.3867058
# The loss is :  1.3864238
# The loss is :  1.3861437
# The loss is :  1.3858652
# The loss is :  1.3855886
# The loss is :  1.385314
# The loss is :  1.3850409
# The loss is :  1.3847696
# The loss is :  1.3844998
# The loss is :  1.3842319
# The loss is :  1.3839658
# The loss is :  1.3837013
# The loss is :  1.3834386
# The loss is :  1.3831773
# The loss is :  1.3829178
# The loss is :  1.3826599
# The loss is :  1.3824035
# The loss is :  1.3821487
# The loss is :  1.3818958
# The loss is :  1.3816442
# The loss is :  1.3813941
# The loss is :  1.3811457
# The loss is :  1.3808987
# The loss is :  1.3806535
# The loss is :  1.3804095
# The loss is :  1.3801671
# The loss is :  1.3799261
# The loss is :  1.3796868
# The loss is :  1.3794488
# The loss is :  1.3792124
# The loss is :  1.3789772
# The loss is :  1.3787434
# The loss is :  1.3785111
# The loss is :  1.3782803
# The loss is :  1.3780508
# The loss is :  1.3778228
# The loss is :  1.377596
# The loss is :  1.3773706
# The loss is :  1.3771466
# The loss is :  1.3769238
# The loss is :  1.3767023
# The loss is :  1.3764824
# The loss is :  1.3762636
# The loss is :  1.3760462
# The loss is :  1.3758299
# The loss is :  1.3756151
# The loss is :  1.3754015
# The loss is :  1.3751891
# The loss is :  1.374978
# The loss is :  1.374768
# The loss is :  1.3745592
# The loss is :  1.3743517
# The loss is :  1.3741454
# The loss is :  1.3739405
# The loss is :  1.3737365
# The loss is :  1.3735337
# The loss is :  1.373332
# The loss is :  1.3731318
# The loss is :  1.3729324
# The loss is :  1.3727344
# The loss is :  1.3725373
# The loss is :  1.3723415
# The loss is :  1.3721468
# The loss is :  1.371953
# The loss is :  1.3717606
# The loss is :  1.3715692
# The loss is :  1.3713789
# The loss is :  1.3711896
# The loss is :  1.3710014
# The loss is :  1.3708143
# The loss is :  1.3706281
# The loss is :  1.3704431
# The loss is :  1.370259
# The loss is :  1.3700761
# The loss is :  1.369894
# The loss is :  1.369713
# The loss is :  1.3695328
# The loss is :  1.3693539
# The loss is :  1.3691759
# The loss is :  1.3689989
# The loss is :  1.3688229
# The loss is :  1.3686478
# The loss is :  1.3684738
# The loss is :  1.3683006
# The loss is :  1.3681284
# The loss is :  1.3679571
# The loss is :  1.3677866
# The loss is :  1.3676175
# The loss is :  1.3674489
# The loss is :  1.3672813
# The loss is :  1.3671147
# The loss is :  1.3669487
# The loss is :  1.366784
# The loss is :  1.3666198
# The loss is :  1.3664567
# The loss is :  1.3662945
# The loss is :  1.3661331
# The loss is :  1.3659726
# The loss is :  1.365813
# The loss is :  1.3656542
# The loss is :  1.3654962
# The loss is :  1.3653392
# The loss is :  1.3651828
# The loss is :  1.3650273
# The loss is :  1.3648728
# The loss is :  1.3647186
# The loss is :  1.3645657
# The loss is :  1.3644135
# The loss is :  1.364262
# The loss is :  1.3641114
# The loss is :  1.3639615
# The loss is :  1.3638124
# The loss is :  1.363664
# The loss is :  1.3635166
# The loss is :  1.3633697
# The loss is :  1.3632238
# The loss is :  1.3630786
# The loss is :  1.362934
# The loss is :  1.3627901
# The loss is :  1.362647
# The loss is :  1.3625048
# The loss is :  1.3623632
# The loss is :  1.3622223
# The loss is :  1.3620825
# The loss is :  1.361943
# The loss is :  1.3618042
# The loss is :  1.3616662
# The loss is :  1.3615288
# The loss is :  1.3613923
# The loss is :  1.3612565
# The loss is :  1.3611209
# The loss is :  1.3609865
# The loss is :  1.3608527
# The loss is :  1.3607193
# The loss is :  1.3605869
# The loss is :  1.360455
# The loss is :  1.3603238
# The loss is :  1.3601933
# The loss is :  1.3600632
# The loss is :  1.359934
# The loss is :  1.3598053
# The loss is :  1.3596774
# The loss is :  1.3595501
# The loss is :  1.3594232
# The loss is :  1.359297
# The loss is :  1.3591716
# The loss is :  1.3590467
# The loss is :  1.3589224
# The loss is :  1.3587989
# The loss is :  1.3586757
# The loss is :  1.3585533
# The loss is :  1.3584313
# The loss is :  1.35831
# The loss is :  1.3581895
# The loss is :  1.3580694
# The loss is :  1.3579497
# The loss is :  1.357831
# The loss is :  1.3577126
# The loss is :  1.3575946
# The loss is :  1.3574775
# The loss is :  1.3573607
# The loss is :  1.3572446
# The loss is :  1.3571291
# The loss is :  1.3570142
# The loss is :  1.3568997
# The loss is :  1.3567858
# The loss is :  1.3566724
# The loss is :  1.3565594
# The loss is :  1.3564472
# The loss is :  1.3563354
# The loss is :  1.3562242
# The loss is :  1.3561134
# The loss is :  1.3560033
# The loss is :  1.3558935
# The loss is :  1.3557844
# The loss is :  1.3556757
# The loss is :  1.3555677
# The loss is :  1.3554599
# The loss is :  1.3553528
# The loss is :  1.3552462
# The loss is :  1.35514
# The loss is :  1.3550345
# The loss is :  1.3549292
# The loss is :  1.3548245
# The loss is :  1.3547204
# The loss is :  1.3546166
# The loss is :  1.3545134
# The loss is :  1.3544106
# The loss is :  1.3543082
# The loss is :  1.3542066
# The loss is :  1.3541051
# The loss is :  1.3540043
# The loss is :  1.3539038
# The loss is :  1.3538039
# The loss is :  1.3537042
# The loss is :  1.3536053
# The loss is :  1.3535067
# The loss is :  1.3534085
# The loss is :  1.3533106
# The loss is :  1.3532133
# The loss is :  1.3531165
# The loss is :  1.3530201
# The loss is :  1.3529241
# The loss is :  1.3528285
# The loss is :  1.3527335
# The loss is :  1.3526387
# The loss is :  1.3525444
# The loss is :  1.3524505
# The loss is :  1.3523571
# The loss is :  1.352264
# The loss is :  1.3521715
# The loss is :  1.3520794
# The loss is :  1.3519875
# The loss is :  1.3518962
# The loss is :  1.3518052
# The loss is :  1.3517146
# The loss is :  1.3516244
# The loss is :  1.3515347
# The loss is :  1.3514453
# The loss is :  1.3513564
# The loss is :  1.3512677
# The loss is :  1.3511795
# The loss is :  1.3510916
# The loss is :  1.3510041
# The loss is :  1.3509171
# The loss is :  1.3508304
# The loss is :  1.350744
# The loss is :  1.350658
# The loss is :  1.3505726
# The loss is :  1.3504874
# The loss is :  1.3504025
# The loss is :  1.350318
# The loss is :  1.3502339
# The loss is :  1.3501501
# The loss is :  1.3500668
# The loss is :  1.3499837
# The loss is :  1.3499011
# The loss is :  1.3498186
# The loss is :  1.3497368
# The loss is :  1.3496549
# The loss is :  1.3495739
# The loss is :  1.349493
# The loss is :  1.3494123
# The loss is :  1.349332
# The loss is :  1.3492521
# The loss is :  1.3491726
# The loss is :  1.3490934
# The loss is :  1.3490145
# The loss is :  1.3489358
# The loss is :  1.3488576
# The loss is :  1.3487798
# The loss is :  1.3487022
# The loss is :  1.3486248
# The loss is :  1.3485479
# The loss is :  1.3484714
# The loss is :  1.3483951
# The loss is :  1.348319
# The loss is :  1.3482434
# The loss is :  1.3481681
# The loss is :  1.3480932
# The loss is :  1.3480184
# The loss is :  1.3479439
# The loss is :  1.3478698
# The loss is :  1.3477961
# The loss is :  1.3477225
# The loss is :  1.3476495
# The loss is :  1.3475765
# The loss is :  1.3475039
# The loss is :  1.3474317
# The loss is :  1.3473595
# The loss is :  1.3472879
# The loss is :  1.3472165
# The loss is :  1.3471453
# The loss is :  1.3470745
# The loss is :  1.3470039
# The loss is :  1.3469336
# The loss is :  1.3468637
# The loss is :  1.346794
# The loss is :  1.3467245
# The loss is :  1.3466555
# The loss is :  1.3465866
# The loss is :  1.346518
# The loss is :  1.3464497
# The loss is :  1.3463817
# The loss is :  1.3463138
# The loss is :  1.3462465
# The loss is :  1.3461791
# The loss is :  1.3461123
# The loss is :  1.3460456
# The loss is :  1.3459792
# The loss is :  1.345913
# The loss is :  1.3458471
# The loss is :  1.3457816
# The loss is :  1.3457162
# The loss is :  1.345651
# The loss is :  1.3455862
# The loss is :  1.3455216
# The loss is :  1.3454574
# The loss is :  1.3453932
# The loss is :  1.3453293
# The loss is :  1.3452659
# The loss is :  1.3452024
# The loss is :  1.3451394
# The loss is :  1.3450766
# The loss is :  1.345014
# The loss is :  1.3449516
# The loss is :  1.3448896
# The loss is :  1.3448277
# The loss is :  1.344766
# The loss is :  1.3447046
# The loss is :  1.3446436
# The loss is :  1.3445827
# The loss is :  1.344522
# The loss is :  1.3444616
# The loss is :  1.3444014
# The loss is :  1.3443414
# The loss is :  1.3442817
# The loss is :  1.3442222
# The loss is :  1.3441628
# The loss is :  1.3441038
# The loss is :  1.3440449
# The loss is :  1.3439864
# The loss is :  1.343928
# The loss is :  1.3438699
# The loss is :  1.343812
# The loss is :  1.3437543
# The loss is :  1.3436968
# The loss is :  1.3436395
# The loss is :  1.3435825
# The loss is :  1.3435256
# The loss is :  1.343469
# The loss is :  1.3434126
# The loss is :  1.3433564
# The loss is :  1.3433005
# The loss is :  1.3432447
# The loss is :  1.3431891
# The loss is :  1.3431337
# The loss is :  1.3430785
# The loss is :  1.3430238
# The loss is :  1.342969
# The loss is :  1.3429145
# The loss is :  1.3428601
# The loss is :  1.342806
# The loss is :  1.3427521
# The loss is :  1.3426983
# The loss is :  1.3426448
# The loss is :  1.3425914
# The loss is :  1.3425384
# The loss is :  1.3424854
# The loss is :  1.3424329
# The loss is :  1.3423802
# The loss is :  1.3423281
# The loss is :  1.3422757
# The loss is :  1.3422238
# The loss is :  1.3421719
# The loss is :  1.3421204
# The loss is :  1.3420691
# The loss is :  1.3420179
# The loss is :  1.341967
# The loss is :  1.3419161
# The loss is :  1.3418654
# The loss is :  1.341815
# The loss is :  1.3417647
# The loss is :  1.3417147
# The loss is :  1.3416648
# The loss is :  1.341615
# The loss is :  1.3415655
# The loss is :  1.3415163
# The loss is :  1.341467
# The loss is :  1.341418
# The loss is :  1.3413693
# The loss is :  1.3413206
# The loss is :  1.341272
# The loss is :  1.341224
# The loss is :  1.3411757
# The loss is :  1.3411279
# The loss is :  1.34108
# The loss is :  1.3410324
# The loss is :  1.340985
# The loss is :  1.3409376
# The loss is :  1.3408906
# The loss is :  1.3408438
# The loss is :  1.3407971
# The loss is :  1.3407503
# The loss is :  1.3407038
# The loss is :  1.3406576
# The loss is :  1.3406116
# The loss is :  1.3405657
# The loss is :  1.3405199
# The loss is :  1.3404742
# The loss is :  1.340429
# The loss is :  1.3403835
# The loss is :  1.3403385
# The loss is :  1.3402934
# The loss is :  1.3402488
# The loss is :  1.340204
# The loss is :  1.3401595
# The loss is :  1.3401152
# The loss is :  1.3400711
# The loss is :  1.340027
# The loss is :  1.3399831
# The loss is :  1.3399394
# The loss is :  1.339896
# The loss is :  1.3398523
# The loss is :  1.3398091
# The loss is :  1.3397661
# The loss is :  1.3397231
# The loss is :  1.3396804
# The loss is :  1.3396376
# The loss is :  1.3395951
# The loss is :  1.3395529
# The loss is :  1.3395104
# The loss is :  1.3394685
# The loss is :  1.3394265
# The loss is :  1.3393849
# The loss is :  1.3393431
# The loss is :  1.3393017
# The loss is :  1.3392602
# The loss is :  1.3392191
# The loss is :  1.339178
# The loss is :  1.3391371
# The loss is :  1.3390963
# The loss is :  1.3390555
# The loss is :  1.3390151
# The loss is :  1.3389748
# The loss is :  1.3389345
# The loss is :  1.3388945
# The loss is :  1.3388546
# The loss is :  1.3388147
# The loss is :  1.3387749
# The loss is :  1.3387353
# The loss is :  1.338696
# The loss is :  1.3386567
# The loss is :  1.3386176
# The loss is :  1.3385783
# The loss is :  1.3385396
# The loss is :  1.3385009
# The loss is :  1.3384622
# The loss is :  1.3384237
# The loss is :  1.3383855
# The loss is :  1.3383471
# The loss is :  1.338309
# The loss is :  1.338271
# The loss is :  1.3382331
# The loss is :  1.3381953
# The loss is :  1.3381578
# The loss is :  1.3381203
# The loss is :  1.3380829
# The loss is :  1.3380457
# The loss is :  1.3380085
# The loss is :  1.3379716
# The loss is :  1.3379347
# The loss is :  1.337898
# The loss is :  1.3378613
# The loss is :  1.3378248
# The loss is :  1.3377886
# The loss is :  1.3377523
# The loss is :  1.3377161
# The loss is :  1.3376801
# The loss is :  1.3376442
# The loss is :  1.3376085
# The loss is :  1.3375728
# The loss is :  1.3375372
# The loss is :  1.3375018
# The loss is :  1.3374665
# The loss is :  1.3374313
# The loss is :  1.3373963
# The loss is :  1.3373613
# The loss is :  1.3373263
# The loss is :  1.3372916
# The loss is :  1.337257
# The loss is :  1.3372225
# The loss is :  1.337188
# The loss is :  1.3371537
# The loss is :  1.3371196
# The loss is :  1.3370855
# The loss is :  1.3370515
# The loss is :  1.3370178
# The loss is :  1.336984
# The loss is :  1.3369504
# The loss is :  1.3369169
# The loss is :  1.3368834
# The loss is :  1.3368502
# The loss is :  1.3368169
# The loss is :  1.3367838
# The loss is :  1.3367507
# The loss is :  1.336718
# The loss is :  1.3366852
# The loss is :  1.3366525
# The loss is :  1.3366199
# The loss is :  1.3365874
# The loss is :  1.336555
# The loss is :  1.3365228
# The loss is :  1.3364906
# The loss is :  1.3364588
# The loss is :  1.3364267
# The loss is :  1.3363948
# The loss is :  1.3363632
# The loss is :  1.3363314
# The loss is :  1.3362998
# The loss is :  1.3362684
# The loss is :  1.3362371
# The loss is :  1.3362058
# The loss is :  1.3361747
# The loss is :  1.3361436
# The loss is :  1.3361127
# The loss is :  1.3360817
# The loss is :  1.336051
# The loss is :  1.3360204
# The loss is :  1.3359898
# The loss is :  1.3359592
# The loss is :  1.3359289
# The loss is :  1.3358985
# The loss is :  1.3358684
# The loss is :  1.3358382
# The loss is :  1.3358082
# The loss is :  1.3357784
# The loss is :  1.3357487
# The loss is :  1.3357189
# The loss is :  1.3356892
# The loss is :  1.3356597
# The loss is :  1.3356302
# The loss is :  1.3356009
# The loss is :  1.3355716
# The loss is :  1.3355423
# The loss is :  1.3355132
# The loss is :  1.3354844
# The loss is :  1.3354554
# The loss is :  1.3354266
# The loss is :  1.3353978
# The loss is :  1.3353692
# The loss is :  1.3353407
# The loss is :  1.3353122
# The loss is :  1.3352839
# The loss is :  1.3352556
# The loss is :  1.3352274
# The loss is :  1.3351992
# The loss is :  1.3351712
# The loss is :  1.3351431
# The loss is :  1.3351154
# The loss is :  1.3350877
# The loss is :  1.3350599
# The loss is :  1.3350323
# The loss is :  1.3350048
# The loss is :  1.3349773
# The loss is :  1.3349502
# The loss is :  1.3349227
# The loss is :  1.3348954
# The loss is :  1.3348684
# The loss is :  1.3348414
# The loss is :  1.3348144
# The loss is :  1.3347875
# The loss is :  1.3347607
# The loss is :  1.334734
# The loss is :  1.3347074
# The loss is :  1.3346808
# The loss is :  1.3346545
# The loss is :  1.3346281
# The loss is :  1.3346015
# The loss is :  1.3345754
# The loss is :  1.3345492
# The loss is :  1.3345232
# The loss is :  1.3344972
# The loss is :  1.3344713
# The loss is :  1.3344454
# The loss is :  1.3344197
# The loss is :  1.3343939
# The loss is :  1.3343682
# The loss is :  1.3343427
# The loss is :  1.3343172
# The loss is :  1.3342919
# The loss is :  1.3342665
# The loss is :  1.3342414
# The loss is :  1.3342161
# The loss is :  1.3341911
# The loss is :  1.3341662
# The loss is :  1.334141
# The loss is :  1.3341163
# The loss is :  1.3340915
# The loss is :  1.3340667
# The loss is :  1.3340422
# The loss is :  1.3340175
# The loss is :  1.333993
# The loss is :  1.3339685
# The loss is :  1.3339442
# The loss is :  1.33392
# The loss is :  1.3338957
# The loss is :  1.3338715
# The loss is :  1.3338475
# The loss is :  1.3338234
# The loss is :  1.3337995
# The loss is :  1.3337756
# The loss is :  1.3337518
# The loss is :  1.333728
# The loss is :  1.3337044
# The loss is :  1.3336807
# The loss is :  1.3336573
# The loss is :  1.3336338
# The loss is :  1.3336104
# The loss is :  1.333587
# The loss is :  1.3335638
# The loss is :  1.3335407
# The loss is :  1.3335174
# The loss is :  1.3334944
# The loss is :  1.3334713
# The loss is :  1.3334484
# The loss is :  1.3334255
# The loss is :  1.3334028
# The loss is :  1.3333801
# The loss is :  1.3333575
# The loss is :  1.3333348
# The loss is :  1.3333122
# The loss is :  1.3332899
# The loss is :  1.3332673
# The loss is :  1.333245
# The loss is :  1.3332226
# The loss is :  1.3332005
# The loss is :  1.3331784
# The loss is :  1.3331561
# The loss is :  1.3331342
# The loss is :  1.3331121
# The loss is :  1.3330904
# The loss is :  1.3330684
# The loss is :  1.3330467
# The loss is :  1.333025
# The loss is :  1.3330032
# The loss is :  1.3329817
# The loss is :  1.33296
# The loss is :  1.3329386
# The loss is :  1.3329172
# The loss is :  1.3328959
# The loss is :  1.3328745
# The loss is :  1.3328532
# The loss is :  1.3328321
# The loss is :  1.332811
# The loss is :  1.3327899
# The loss is :  1.3327689
# The loss is :  1.3327478
# The loss is :  1.3327271
# The loss is :  1.3327063
# The loss is :  1.3326855
# The loss is :  1.3326647
# The loss is :  1.332644
# The loss is :  1.3326234
# The loss is :  1.3326027
# The loss is :  1.3325824
# The loss is :  1.3325619
# The loss is :  1.3325415
# The loss is :  1.3325212
# The loss is :  1.3325009
# The loss is :  1.3324807
# The loss is :  1.3324605
# The loss is :  1.3324404
# The loss is :  1.3324203
# The loss is :  1.3324003
# The loss is :  1.3323804
# The loss is :  1.3323605
# The loss is :  1.3323407
# The loss is :  1.3323209
# The loss is :  1.3323011
# The loss is :  1.3322815
# The loss is :  1.3322618
# The loss is :  1.3322424
# The loss is :  1.3322228
# The loss is :  1.3322034
# The loss is :  1.332184
# The loss is :  1.3321646
# The loss is :  1.3321453
# The loss is :  1.332126
# The loss is :  1.332107
# The loss is :  1.3320878
# The loss is :  1.3320687
# The loss is :  1.3320496
# The loss is :  1.3320307
# The loss is :  1.3320117
# The loss is :  1.3319926
# The loss is :  1.3319739
# The loss is :  1.3319551
# The loss is :  1.3319365
# The loss is :  1.3319178
# The loss is :  1.3318992
# The loss is :  1.3318805
# The loss is :  1.3318621
# The loss is :  1.3318435
# The loss is :  1.331825
# The loss is :  1.3318067
# The loss is :  1.3317883
# The loss is :  1.3317701
# The loss is :  1.3317517
# The loss is :  1.3317336
# The loss is :  1.3317156
# The loss is :  1.3316973
# The loss is :  1.3316793
# The loss is :  1.3316613
# The loss is :  1.3316432
# The loss is :  1.3316255
# The loss is :  1.3316075
# The loss is :  1.3315897
# The loss is :  1.3315719
# The loss is :  1.3315543
# The loss is :  1.3315365
# The loss is :  1.3315191
# The loss is :  1.3315015
# The loss is :  1.3314838
# The loss is :  1.3314663
# The loss is :  1.3314488
# The loss is :  1.3314315
# The loss is :  1.3314141
# The loss is :  1.3313969
# The loss is :  1.3313797
# The loss is :  1.3313624
# The loss is :  1.3313452
# The loss is :  1.331328
# The loss is :  1.331311
# The loss is :  1.3312938
# The loss is :  1.3312769
# The loss is :  1.33126
# The loss is :  1.3312429
# The loss is :  1.3312262
# The loss is :  1.3312095
# The loss is :  1.3311926
# The loss is :  1.3311758
# The loss is :  1.3311591
# The loss is :  1.3311425
# The loss is :  1.331126
# The loss is :  1.3311093
# The loss is :  1.3310927
# The loss is :  1.3310765
# The loss is :  1.3310599
# The loss is :  1.3310435
# The loss is :  1.3310272
# The loss is :  1.3310109
# The loss is :  1.3309945
# The loss is :  1.3309783
# The loss is :  1.3309622
# The loss is :  1.330946
# The loss is :  1.3309298
# The loss is :  1.3309138
# The loss is :  1.3308978
# The loss is :  1.330882
# The loss is :  1.330866
# The loss is :  1.3308499
# The loss is :  1.3308342
# The loss is :  1.3308182
# The loss is :  1.3308026
# The loss is :  1.3307867
# The loss is :  1.3307712
# The loss is :  1.3307554
# The loss is :  1.3307397
# The loss is :  1.3307241
# The loss is :  1.3307085
# The loss is :  1.3306932
# The loss is :  1.3306777
# The loss is :  1.3306624
# The loss is :  1.3306469
# The loss is :  1.3306315
# The loss is :  1.3306161
# The loss is :  1.330601
# The loss is :  1.3305857
# The loss is :  1.3305705
# The loss is :  1.3305553
# The loss is :  1.3305403
# The loss is :  1.330525
# The loss is :  1.3305101
# The loss is :  1.3304949
# The loss is :  1.33048
# The loss is :  1.3304652
# The loss is :  1.3304503
# The loss is :  1.3304354
# The loss is :  1.3304206
# The loss is :  1.3304056
# The loss is :  1.3303909
# The loss is :  1.3303763
# The loss is :  1.3303615
# The loss is :  1.330347
# The loss is :  1.3303324
# The loss is :  1.3303177
# The loss is :  1.3303032
# The loss is :  1.3302888
# The loss is :  1.3302742
# The loss is :  1.3302599
# The loss is :  1.3302455
# The loss is :  1.3302311
# The loss is :  1.3302166
# The loss is :  1.3302026
# The loss is :  1.3301882
# The loss is :  1.3301741
# The loss is :  1.3301598
# The loss is :  1.3301457
# The loss is :  1.3301316
# The loss is :  1.3301173
# The loss is :  1.3301034
# The loss is :  1.3300894
# The loss is :  1.3300753
# The loss is :  1.3300616
# The loss is :  1.3300475
# The loss is :  1.3300337
# The loss is :  1.3300198
# The loss is :  1.3300061
# The loss is :  1.3299922
# The loss is :  1.3299785
# The loss is :  1.3299648
# The loss is :  1.329951
# The loss is :  1.3299376
# The loss is :  1.3299239
# The loss is :  1.3299102
# The loss is :  1.3298968
# The loss is :  1.3298831
# The loss is :  1.3298696
# The loss is :  1.3298562
# The loss is :  1.3298428
# The loss is :  1.3298293
# The loss is :  1.3298161
# The loss is :  1.3298029
# The loss is :  1.3297894
# The loss is :  1.3297762
# The loss is :  1.3297629
# The loss is :  1.3297498
# The loss is :  1.3297366
# The loss is :  1.3297235
# The loss is :  1.3297104
# The loss is :  1.3296975
# The loss is :  1.3296843
# The loss is :  1.3296713
# The loss is :  1.3296583
# The loss is :  1.3296454
# The loss is :  1.3296324
# The loss is :  1.3296195
# The loss is :  1.3296067
# The loss is :  1.3295939
# The loss is :  1.3295811
# The loss is :  1.3295683
# The loss is :  1.3295555
# The loss is :  1.3295429
# The loss is :  1.3295301
# The loss is :  1.3295175
# The loss is :  1.329505
# The loss is :  1.3294923
# The loss is :  1.3294797
# The loss is :  1.3294673
# The loss is :  1.3294547
# The loss is :  1.329442
# The loss is :  1.3294297
# The loss is :  1.3294173
# The loss is :  1.3294051
# The loss is :  1.3293924
# The loss is :  1.3293804
# The loss is :  1.329368
# The loss is :  1.3293557
# The loss is :  1.3293433
# The loss is :  1.3293313
# The loss is :  1.329319
# The loss is :  1.3293068
# The loss is :  1.3292948
# The loss is :  1.3292825
# The loss is :  1.3292705
# The loss is :  1.3292584
# The loss is :  1.3292464
# The loss is :  1.3292345
# The loss is :  1.3292226
# The loss is :  1.3292105
# The loss is :  1.3291986
# The loss is :  1.3291867
# The loss is :  1.3291748
# The loss is :  1.329163
# The loss is :  1.3291513
# The loss is :  1.3291394
# The loss is :  1.3291277
# The loss is :  1.3291159
# The loss is :  1.3291043
# The loss is :  1.3290926
# The loss is :  1.329081
# The loss is :  1.3290693
# The loss is :  1.3290578
# The loss is :  1.3290461
# The loss is :  1.3290347
# The loss is :  1.3290231
# The loss is :  1.3290117
# The loss is :  1.3290002
# The loss is :  1.3289888
# The loss is :  1.3289773
# The loss is :  1.328966
# The loss is :  1.3289547
# The loss is :  1.3289433
# The loss is :  1.3289319
# The loss is :  1.3289206
# The loss is :  1.3289095
# The loss is :  1.3288983
# The loss is :  1.328887
# The loss is :  1.3288759
# The loss is :  1.3288647
# The loss is :  1.3288535
# The loss is :  1.3288425
# The loss is :  1.3288314
# The loss is :  1.3288202
# The loss is :  1.3288091
# The loss is :  1.3287983
# The loss is :  1.3287873
# The loss is :  1.3287764
# The loss is :  1.3287653
# The loss is :  1.3287544
# The loss is :  1.3287436
# The loss is :  1.3287326
# The loss is :  1.3287218
# The loss is :  1.328711
# The loss is :  1.3287002
# The loss is :  1.3286895
# The loss is :  1.3286788
# The loss is :  1.328668
# The loss is :  1.3286574
# The loss is :  1.3286465
# The loss is :  1.3286359
# The loss is :  1.3286253
# The loss is :  1.3286148
# The loss is :  1.3286042
# The loss is :  1.3285935
# The loss is :  1.3285832
# The loss is :  1.3285726
# The loss is :  1.3285621
# The loss is :  1.3285517
# The loss is :  1.3285413
# The loss is :  1.3285307
# The loss is :  1.3285204
# The loss is :  1.3285099
# The loss is :  1.3284997
# The loss is :  1.3284893
# The loss is :  1.3284789
# The loss is :  1.3284688
# The loss is :  1.3284584
# The loss is :  1.3284483
# The loss is :  1.3284379
# The loss is :  1.3284278
# The loss is :  1.3284178
# The loss is :  1.3284075
# The loss is :  1.3283974
# The loss is :  1.3283873
# The loss is :  1.3283772
# The loss is :  1.3283672
# The loss is :  1.3283571
# The loss is :  1.3283472
# The loss is :  1.3283371
# The loss is :  1.3283271
# The loss is :  1.3283172
# The loss is :  1.3283072
# The loss is :  1.3282974
# The loss is :  1.3282875
# The loss is :  1.3282775
# The loss is :  1.3282676
# The loss is :  1.3282578
# The loss is :  1.328248
# The loss is :  1.3282381
# The loss is :  1.3282285
# The loss is :  1.3282188
# The loss is :  1.3282089
# The loss is :  1.3281994
# The loss is :  1.3281897
# The loss is :  1.3281798
# The loss is :  1.3281702
# The loss is :  1.3281606
# The loss is :  1.328151
# The loss is :  1.3281415
# The loss is :  1.3281319
# The loss is :  1.3281223
# The loss is :  1.3281128
# The loss is :  1.3281033
# The loss is :  1.3280939
# The loss is :  1.3280843
# The loss is :  1.328075
# The loss is :  1.3280656
# The loss is :  1.328056
# The loss is :  1.3280468
# The loss is :  1.3280374
# The loss is :  1.3280281
# The loss is :  1.3280188
# The loss is :  1.3280095
# The loss is :  1.3280001
# The loss is :  1.3279909
# The loss is :  1.3279815
# The loss is :  1.3279724
# The loss is :  1.3279631
# The loss is :  1.327954
# The loss is :  1.3279448
# The loss is :  1.3279357
# The loss is :  1.3279265
# The loss is :  1.3279173
# The loss is :  1.3279083
# The loss is :  1.3278992
# The loss is :  1.3278902
# The loss is :  1.3278813
# The loss is :  1.3278723
# The loss is :  1.3278632
# The loss is :  1.3278542
# The loss is :  1.3278452
# The loss is :  1.3278362
# The loss is :  1.3278273
# The loss is :  1.3278185
# The loss is :  1.3278095
# The loss is :  1.3278006
# The loss is :  1.3277919
# The loss is :  1.327783
# The loss is :  1.3277742
# The loss is :  1.3277653
# The loss is :  1.3277565
# The loss is :  1.3277478
# The loss is :  1.327739
# The loss is :  1.3277303
# The loss is :  1.3277216
# The loss is :  1.3277128
# The loss is :  1.3277043
# The loss is :  1.3276956
# The loss is :  1.327687
# The loss is :  1.3276782
# The loss is :  1.3276697
# The loss is :  1.327661
# The loss is :  1.3276527
# The loss is :  1.327644
# The loss is :  1.3276355
# The loss is :  1.3276268
# The loss is :  1.3276186
# The loss is :  1.32761
# The loss is :  1.3276016
# The loss is :  1.3275931
# The loss is :  1.3275846
# The loss is :  1.3275763
# The loss is :  1.3275678
# The loss is :  1.3275595
# The loss is :  1.3275511
# The loss is :  1.3275428
# The loss is :  1.3275346
# The loss is :  1.327526
# The loss is :  1.3275177
# The loss is :  1.3275095
# The loss is :  1.3275012
# The loss is :  1.327493
# The loss is :  1.3274848
# The loss is :  1.3274765
# The loss is :  1.3274683
# The loss is :  1.3274602
# The loss is :  1.327452
# The loss is :  1.3274438
# The loss is :  1.3274357
# The loss is :  1.3274277
# The loss is :  1.3274195
# The loss is :  1.3274115
# The loss is :  1.3274032
# The loss is :  1.3273954
# The loss is :  1.3273873
# The loss is :  1.3273792
# The loss is :  1.3273712
# The loss is :  1.3273633
# The loss is :  1.3273551
# The loss is :  1.3273473
# The loss is :  1.3273394
# The loss is :  1.3273314
# The loss is :  1.3273236
# The loss is :  1.3273156
# The loss is :  1.3273077
# The loss is :  1.3273
# The loss is :  1.327292
# The loss is :  1.3272842
# The loss is :  1.3272765
# The loss is :  1.3272686
# The loss is :  1.3272607
# The loss is :  1.327253
# The loss is :  1.3272452
# The loss is :  1.3272375
# The loss is :  1.3272297
# The loss is :  1.327222
# The loss is :  1.3272144
# The loss is :  1.3272066
# The loss is :  1.327199
# The loss is :  1.3271914
# The loss is :  1.3271837
# The loss is :  1.3271761
# The loss is :  1.3271685
# The loss is :  1.327161
# The loss is :  1.3271532
# The loss is :  1.3271457
# The loss is :  1.3271382
# The loss is :  1.3271306
# The loss is :  1.327123
# The loss is :  1.3271157
# The loss is :  1.327108
# The loss is :  1.3271006
# The loss is :  1.3270932
# The loss is :  1.3270857
# The loss is :  1.3270782
# The loss is :  1.3270711
# The loss is :  1.3270636
# The loss is :  1.327056
# The loss is :  1.3270487
# The loss is :  1.3270413
# The loss is :  1.327034
# The loss is :  1.3270267
# The loss is :  1.3270195
# The loss is :  1.3270121
# The loss is :  1.3270047
# The loss is :  1.3269974
# The loss is :  1.3269902
# The loss is :  1.3269831
# The loss is :  1.3269758
# The loss is :  1.3269686
# The loss is :  1.3269613
# The loss is :  1.326954
# The loss is :  1.326947
# The loss is :  1.3269397
# The loss is :  1.3269327
# The loss is :  1.3269254
# The loss is :  1.3269184
# The loss is :  1.3269112
# The loss is :  1.326904
# The loss is :  1.3268969
# The loss is :  1.32689
# The loss is :  1.3268827
# The loss is :  1.3268758
# The loss is :  1.3268688
# The loss is :  1.3268617
# The loss is :  1.3268548
# The loss is :  1.3268478
# The loss is :  1.3268408
# The loss is :  1.3268338
# The loss is :  1.3268268
# The loss is :  1.3268198
# The loss is :  1.3268129
# The loss is :  1.3268061
# The loss is :  1.326799
# The loss is :  1.3267922
# The loss is :  1.3267852
# The loss is :  1.3267784
# The loss is :  1.3267717
# The loss is :  1.3267647
# The loss is :  1.326758
# The loss is :  1.3267511
# The loss is :  1.3267443
# The loss is :  1.3267375
# The loss is :  1.3267306
# The loss is :  1.3267239
# The loss is :  1.3267171
# The loss is :  1.3267106
# The loss is :  1.3267038
# The loss is :  1.3266971
# The loss is :  1.3266903
# The loss is :  1.3266838
# The loss is :  1.326677
# The loss is :  1.3266703
# The loss is :  1.3266636
# The loss is :  1.326657
# The loss is :  1.3266504
# The loss is :  1.3266437
# The loss is :  1.3266371
# The loss is :  1.3266306
# The loss is :  1.326624
# The loss is :  1.3266172
# The loss is :  1.3266109
# The loss is :  1.3266042
# The loss is :  1.3265978
# The loss is :  1.3265913
# The loss is :  1.3265847
# The loss is :  1.3265781
# The loss is :  1.3265718
# The loss is :  1.3265654
# The loss is :  1.3265588
# The loss is :  1.3265524
# The loss is :  1.326546
# The loss is :  1.3265394
# The loss is :  1.3265332
# The loss is :  1.3265266
# The loss is :  1.3265203
# The loss is :  1.326514
# The loss is :  1.3265076
# The loss is :  1.3265011
# The loss is :  1.3264948
# The loss is :  1.3264885
# The loss is :  1.3264822
# The loss is :  1.3264759
# The loss is :  1.3264697
# The loss is :  1.3264633
# The loss is :  1.326457
# The loss is :  1.3264507
# The loss is :  1.3264445
# The loss is :  1.3264382
# The loss is :  1.326432
# The loss is :  1.3264259
# The loss is :  1.3264196
# The loss is :  1.3264133
# The loss is :  1.3264073
# The loss is :  1.3264011
# The loss is :  1.3263948
# The loss is :  1.3263886
# The loss is :  1.3263826
# The loss is :  1.3263764
# The loss is :  1.3263704
# The loss is :  1.326364
# The loss is :  1.3263581
# The loss is :  1.3263521
# The loss is :  1.3263459
# The loss is :  1.3263398
# The loss is :  1.3263339
# The loss is :  1.3263277
# The loss is :  1.3263216
# The loss is :  1.3263156
# The loss is :  1.3263097
# The loss is :  1.3263036
# The loss is :  1.3262976
# The loss is :  1.3262917
# The loss is :  1.3262855
# The loss is :  1.3262796
# The loss is :  1.3262738
# The loss is :  1.3262678
# The loss is :  1.3262619
# The loss is :  1.3262559
# The loss is :  1.32625
# The loss is :  1.3262441
# The loss is :  1.3262383
# The loss is :  1.3262324
# The loss is :  1.3262266
# The loss is :  1.3262206
# The loss is :  1.3262148
# The loss is :  1.326209
# The loss is :  1.3262032
# The loss is :  1.3261974
# The loss is :  1.3261915
# The loss is :  1.3261858
# The loss is :  1.32618
# The loss is :  1.3261741
# The loss is :  1.3261684
# The loss is :  1.3261627
# The loss is :  1.3261569
# The loss is :  1.3261511
# The loss is :  1.3261455
# The loss is :  1.3261398
# The loss is :  1.326134
# The loss is :  1.3261284
# The loss is :  1.3261226
# The loss is :  1.326117
# The loss is :  1.3261113
# The loss is :  1.3261057
# The loss is :  1.3261
# The loss is :  1.3260945
# The loss is :  1.3260887
# The loss is :  1.3260832
# The loss is :  1.3260775
# The loss is :  1.3260717
# The loss is :  1.3260663
# The loss is :  1.3260608
# The loss is :  1.3260552
# The loss is :  1.3260496
# The loss is :  1.3260441
# The loss is :  1.3260385
# The loss is :  1.326033
# The loss is :  1.3260275
# The loss is :  1.326022
# The loss is :  1.3260164
# The loss is :  1.3260108
# The loss is :  1.3260055
# The loss is :  1.326
# The loss is :  1.3259945
# The loss is :  1.325989
# The loss is :  1.3259835
# The loss is :  1.3259783
# The loss is :  1.3259726
# The loss is :  1.3259673
# The loss is :  1.325962
# The loss is :  1.3259566
# The loss is :  1.3259511
# The loss is :  1.3259457
# The loss is :  1.3259404
# The loss is :  1.3259349
# The loss is :  1.3259296
# The loss is :  1.3259243
# The loss is :  1.325919
# The loss is :  1.3259137
# The loss is :  1.3259083
# The loss is :  1.3259029
# The loss is :  1.3258977
# The loss is :  1.3258923
# The loss is :  1.325887
# The loss is :  1.3258817
# The loss is :  1.3258766
# The loss is :  1.3258713
# The loss is :  1.325866
# The loss is :  1.3258607
# The loss is :  1.3258556
# The loss is :  1.3258504
# The loss is :  1.325845
# The loss is :  1.3258399
# The loss is :  1.3258346
# The loss is :  1.3258295
# The loss is :  1.3258243
# The loss is :  1.3258193
# The loss is :  1.325814
# The loss is :  1.3258089
# The loss is :  1.3258038
# The loss is :  1.3257985
# The loss is :  1.3257933
# The loss is :  1.3257884
# The loss is :  1.3257831
# The loss is :  1.325778
# The loss is :  1.3257729
# The loss is :  1.325768
# The loss is :  1.3257627
# The loss is :  1.3257577
# The loss is :  1.3257527
# The loss is :  1.3257477
# The loss is :  1.3257426
# The loss is :  1.3257375
# The loss is :  1.3257326
# The loss is :  1.3257276
# The loss is :  1.3257226
# The loss is :  1.3257174
# The loss is :  1.3257126
# The loss is :  1.3257074
# The loss is :  1.3257025
# The loss is :  1.3256977
# The loss is :  1.3256927
# The loss is :  1.3256876
# The loss is :  1.3256826
# The loss is :  1.3256778
# The loss is :  1.325673
# The loss is :  1.3256679
# The loss is :  1.3256631
# The loss is :  1.3256581
# The loss is :  1.3256532
# The loss is :  1.3256483
# The loss is :  1.3256434
# The loss is :  1.3256385
# The loss is :  1.3256336
# The loss is :  1.3256289
# The loss is :  1.3256241
# The loss is :  1.3256191
# The loss is :  1.3256143
# The loss is :  1.3256094
# The loss is :  1.3256046
# The loss is :  1.3255999
# The loss is :  1.325595
# The loss is :  1.3255904
# The loss is :  1.3255854
# The loss is :  1.3255808
# The loss is :  1.3255758
# The loss is :  1.3255712
# The loss is :  1.3255664
# The loss is :  1.3255616
# The loss is :  1.3255569
# The loss is :  1.3255522
# The loss is :  1.3255473
# The loss is :  1.3255427
# The loss is :  1.325538
# The loss is :  1.3255334
# The loss is :  1.3255286
# The loss is :  1.3255241
# The loss is :  1.3255192
# The loss is :  1.3255147
# The loss is :  1.3255099
# The loss is :  1.3255053
# The loss is :  1.3255007
# The loss is :  1.325496
# The loss is :  1.3254913
# The loss is :  1.3254867
# The loss is :  1.3254821
# The loss is :  1.3254775
# The loss is :  1.3254728
# The loss is :  1.3254683
# The loss is :  1.3254637
# The loss is :  1.3254591
# The loss is :  1.3254545
# The loss is :  1.32545
# The loss is :  1.3254453
# The loss is :  1.3254408
# The loss is :  1.3254365
# The loss is :  1.3254318
# The loss is :  1.325427
# The loss is :  1.3254228
# The loss is :  1.3254181
# The loss is :  1.3254137
# The loss is :  1.3254092
# The loss is :  1.3254045
# The loss is :  1.3254001
# The loss is :  1.3253957
# The loss is :  1.3253912
# The loss is :  1.3253868
# The loss is :  1.3253824
# The loss is :  1.3253778
# The loss is :  1.3253733
# The loss is :  1.325369
# The loss is :  1.3253644
# The loss is :  1.3253602
# The loss is :  1.3253556
# The loss is :  1.3253512
# The loss is :  1.3253468
# The loss is :  1.3253424
# The loss is :  1.325338
# The loss is :  1.3253336
# The loss is :  1.3253293
# The loss is :  1.3253249
# The loss is :  1.3253205
# The loss is :  1.3253162
# The loss is :  1.3253118
# The loss is :  1.3253074
# The loss is :  1.3253031
# The loss is :  1.3252988
# The loss is :  1.3252945
# The loss is :  1.3252902
# The loss is :  1.3252858
# The loss is :  1.3252815
# The loss is :  1.3252772
# The loss is :  1.3252727
# The loss is :  1.3252685
# The loss is :  1.3252645
# The loss is :  1.3252602
# The loss is :  1.3252559
# The loss is :  1.3252515
# The loss is :  1.3252474
# The loss is :  1.325243
# The loss is :  1.3252387
# The loss is :  1.3252345
# The loss is :  1.3252305
# The loss is :  1.3252262
# The loss is :  1.3252218
# The loss is :  1.3252177
# The loss is :  1.3252134
# The loss is :  1.3252093
# The loss is :  1.3252051
# The loss is :  1.3252009
# The loss is :  1.3251966
# The loss is :  1.3251926
# The loss is :  1.3251885
# The loss is :  1.3251842
# The loss is :  1.32518
# The loss is :  1.325176
# The loss is :  1.325172
# The loss is :  1.3251677
# The loss is :  1.3251636
# The loss is :  1.3251594
# The loss is :  1.3251554
# The loss is :  1.3251512
# The loss is :  1.3251473
# The loss is :  1.325143
# The loss is :  1.325139
# The loss is :  1.325135
# The loss is :  1.3251308
# The loss is :  1.3251268
# The loss is :  1.3251226
# The loss is :  1.3251187
# The loss is :  1.3251146
# The loss is :  1.3251106
# The loss is :  1.3251065
# The loss is :  1.3251024
# The loss is :  1.3250985
# The loss is :  1.3250943
# The loss is :  1.3250904
# The loss is :  1.3250865
# The loss is :  1.3250824
# The loss is :  1.3250785
# The loss is :  1.3250743
# The loss is :  1.3250705
# The loss is :  1.3250664
# The loss is :  1.3250625
# The loss is :  1.3250586
# The loss is :  1.3250546
# The loss is :  1.3250506
# The loss is :  1.3250467
# The loss is :  1.3250426
# The loss is :  1.3250389
# The loss is :  1.3250347
# The loss is :  1.3250309
# The loss is :  1.325027
# The loss is :  1.325023
# The loss is :  1.3250191
# The loss is :  1.3250153
# The loss is :  1.3250113
# The loss is :  1.3250076
# The loss is :  1.3250036
# The loss is :  1.3249998
# The loss is :  1.324996
# The loss is :  1.3249921
# The loss is :  1.3249881
# The loss is :  1.3249843
# The loss is :  1.3249806
# The loss is :  1.3249767
# The loss is :  1.3249727
# The loss is :  1.3249689
# The loss is :  1.3249651
# The loss is :  1.3249613
# The loss is :  1.3249576
# The loss is :  1.3249537
# The loss is :  1.32495
# The loss is :  1.324946
# The loss is :  1.3249422
# The loss is :  1.3249385
# The loss is :  1.3249348
# The loss is :  1.3249309
# The loss is :  1.3249271
# The loss is :  1.3249235
# The loss is :  1.3249196
# The loss is :  1.3249159
# The loss is :  1.3249121
# The loss is :  1.3249084
# The loss is :  1.3249047
# The loss is :  1.324901
# The loss is :  1.3248972
# The loss is :  1.3248935
# The loss is :  1.3248898
# The loss is :  1.324886
# The loss is :  1.3248823
# The loss is :  1.3248786
# The loss is :  1.324875
# The loss is :  1.3248713
# The loss is :  1.3248676
# The loss is :  1.3248639
# The loss is :  1.3248602
# The loss is :  1.3248565
# The loss is :  1.324853
# The loss is :  1.3248491
# The loss is :  1.3248456
# The loss is :  1.324842
# The loss is :  1.3248383
# The loss is :  1.3248347
# The loss is :  1.324831
# The loss is :  1.3248273
# The loss is :  1.324824
# The loss is :  1.3248202
# The loss is :  1.3248166
# The loss is :  1.3248129
# The loss is :  1.3248093
# The loss is :  1.3248057
# The loss is :  1.3248022
# The loss is :  1.3247985
# The loss is :  1.324795
# The loss is :  1.3247914
# The loss is :  1.3247877
# The loss is :  1.3247843
# The loss is :  1.3247807
# The loss is :  1.3247771
# The loss is :  1.3247736
# The loss is :  1.32477
# The loss is :  1.3247666
# The loss is :  1.3247631
# The loss is :  1.3247595
# The loss is :  1.3247559
# The loss is :  1.3247524
# The loss is :  1.324749
# The loss is :  1.3247455
# The loss is :  1.324742
# The loss is :  1.3247385
# The loss is :  1.3247348
# The loss is :  1.3247316
# The loss is :  1.324728
# The loss is :  1.3247244
# The loss is :  1.324721
# The loss is :  1.3247175
# The loss is :  1.3247141
# The loss is :  1.3247105
# The loss is :  1.3247072
# The loss is :  1.3247037
# The loss is :  1.3247004
# The loss is :  1.3246968
# The loss is :  1.3246933
# The loss is :  1.32469
# The loss is :  1.3246865
# The loss is :  1.3246832
# The loss is :  1.3246797
# The loss is :  1.3246764
# The loss is :  1.324673
# The loss is :  1.3246696
# The loss is :  1.3246661
# The loss is :  1.3246627
# The loss is :  1.3246595
# The loss is :  1.3246561
# The loss is :  1.3246527
# The loss is :  1.3246492
# The loss is :  1.3246458
# The loss is :  1.3246425
# The loss is :  1.3246392
# The loss is :  1.3246357
# The loss is :  1.3246324
# The loss is :  1.3246291
# The loss is :  1.3246257
# The loss is :  1.3246223
# The loss is :  1.3246192
# The loss is :  1.3246158
# The loss is :  1.3246125
# The loss is :  1.3246092
# The loss is :  1.3246057
# The loss is :  1.3246026
# The loss is :  1.3245993
# The loss is :  1.3245959
# The loss is :  1.3245927
# The loss is :  1.3245894
# The loss is :  1.3245859
# The loss is :  1.3245827
# The loss is :  1.3245795
# The loss is :  1.3245763
# The loss is :  1.3245729
# The loss is :  1.3245697
# The loss is :  1.3245665
# The loss is :  1.3245631
# The loss is :  1.3245599
# The loss is :  1.3245567
# The loss is :  1.3245535
# The loss is :  1.3245503
# The loss is :  1.3245469
# The loss is :  1.3245438
# The loss is :  1.3245404
# The loss is :  1.3245374
# The loss is :  1.3245342
# The loss is :  1.3245308
# The loss is :  1.3245277
# The loss is :  1.3245246
# The loss is :  1.3245213
# The loss is :  1.3245181
# The loss is :  1.324515
# The loss is :  1.3245118
# The loss is :  1.3245084
# The loss is :  1.3245056
# The loss is :  1.3245022
# The loss is :  1.3244991
# The loss is :  1.324496
# The loss is :  1.3244927
# The loss is :  1.3244897
# The loss is :  1.3244866
# The loss is :  1.3244833
# The loss is :  1.3244802
# The loss is :  1.3244771
# The loss is :  1.324474
# The loss is :  1.3244709
# The loss is :  1.3244677
# The loss is :  1.3244647
# The loss is :  1.3244616
# The loss is :  1.3244582
# The loss is :  1.3244553
# The loss is :  1.3244522
# The loss is :  1.3244491
# The loss is :  1.324446
# The loss is :  1.3244429
# ...
# The loss is :  1.3208915
# The loss is :  1.3208914
# The loss is :  1.3208914
# The loss is :  1.3208914
# The loss is :  1.3208914
# The loss is :  1.3208911
# The loss is :  1.3208911
# The loss is :  1.3208911
# The loss is :  1.3208911
# The loss is :  1.320891
# The loss is :  1.320891
# The loss is :  1.3208908
# The loss is :  1.3208908
# The loss is :  1.3208908
# The loss is :  1.3208907
# The loss is :  1.3208905
# The loss is :  1.3208904
# The loss is :  1.3208904
# The loss is :  1.3208903
# The loss is :  1.3208902
# The loss is :  1.3208902
# The loss is :  1.3208902
# The loss is :  1.3208902
# The loss is :  1.32089
# The loss is :  1.32089
# The loss is :  1.3208898
# The loss is :  1.3208898
# The loss is :  1.3208898
# The loss is :  1.3208897
# The loss is :  1.3208896
# The loss is :  1.3208895
# The loss is :  1.3208895
# The loss is :  1.3208895
# The loss is :  1.3208895
# The loss is :  1.3208895
# The loss is :  1.3208894
# The loss is :  1.3208894
# The loss is :  1.3208892
# The loss is :  1.3208892
# The loss is :  1.3208891
# The loss is :  1.3208891
# The loss is :  1.320889
# The loss is :  1.3208889
# The loss is :  1.3208889
# The loss is :  1.3208888
# The loss is :  1.3208886
# The loss is :  1.3208886
# The loss is :  1.3208886
# The loss is :  1.3208885
# The loss is :  1.3208883
# The loss is :  1.3208883
# The loss is :  1.3208883
# The loss is :  1.3208882
# The loss is :  1.3208882
# The loss is :  1.320888
# The loss is :  1.320888
# The loss is :  1.3208879
# The loss is :  1.3208878
# The loss is :  1.3208878
# The loss is :  1.3208878
# The loss is :  1.3208877
# The loss is :  1.3208877
# The loss is :  1.3208876
# The loss is :  1.3208876
# The loss is :  1.3208874
# The loss is :  1.3208874
# The loss is :  1.3208874
# The loss is :  1.3208873
# The loss is :  1.3208872
# The loss is :  1.3208871
# The loss is :  1.3208871
# The loss is :  1.3208871
# The loss is :  1.3208871
# The loss is :  1.3208869
# The loss is :  1.3208869
# The loss is :  1.3208869
# The loss is :  1.3208867
# The loss is :  1.3208865
# The loss is :  1.3208866
# The loss is :  1.3208865
# The loss is :  1.3208865
# The loss is :  1.3208864
# The loss is :  1.3208861
# The loss is :  1.3208861
# The loss is :  1.3208861
# The loss is :  1.3208861
# The loss is :  1.320886
# The loss is :  1.3208859
# The loss is :  1.3208859
# The loss is :  1.3208858
# The loss is :  1.3208858
# The loss is :  1.3208858
# The loss is :  1.3208857
# The loss is :  1.3208857
# The loss is :  1.3208857
# The loss is :  1.3208855
# The loss is :  1.3208853
# The loss is :  1.3208854
# The loss is :  1.3208853
# The loss is :  1.3208852
# The loss is :  1.3208852
# The loss is :  1.3208852
# The loss is :  1.3208852
# The loss is :  1.320885
# The loss is :  1.320885
# The loss is :  1.3208848
# The loss is :  1.3208847
# The loss is :  1.3208848
# The loss is :  1.3208848
# The loss is :  1.3208846
# The loss is :  1.3208846
# The loss is :  1.3208843
# The loss is :  1.3208843
# The loss is :  1.3208843
# The loss is :  1.3208843
# The loss is :  1.3208841
# The loss is :  1.3208841
# The loss is :  1.320884
# The loss is :  1.320884
# The loss is :  1.320884
# The loss is :  1.320884
# The loss is :  1.3208839
# The loss is :  1.3208838
# The loss is :  1.3208838
# The loss is :  1.3208838
# The loss is :  1.3208838
# The loss is :  1.3208835
# The loss is :  1.3208835
# The loss is :  1.3208835
# The loss is :  1.3208835
# The loss is :  1.3208834
# The loss is :  1.3208832
# The loss is :  1.3208832
# The loss is :  1.3208832
# The loss is :  1.3208832
# The loss is :  1.3208832
# The loss is :  1.3208829
# The loss is :  1.3208828
# The loss is :  1.3208828
# The loss is :  1.3208827
# The loss is :  1.3208827
# The loss is :  1.3208827
# The loss is :  1.3208827
# The loss is :  1.3208826
# The loss is :  1.3208823
# The loss is :  1.3208823
# The loss is :  1.3208823
# The loss is :  1.3208822
# The loss is :  1.3208822
# The loss is :  1.3208822
# The loss is :  1.3208821
# The loss is :  1.3208818
# The loss is :  1.3208818
# The loss is :  1.3208818
# The loss is :  1.3208818
# The loss is :  1.3208818
# The loss is :  1.3208817
# The loss is :  1.3208816
# The loss is :  1.3208816
# The loss is :  1.3208816
# The loss is :  1.3208816
# The loss is :  1.3208814
# The loss is :  1.3208814
# The loss is :  1.3208814
# The loss is :  1.3208812
# The loss is :  1.320881
# The loss is :  1.320881
# The loss is :  1.320881
# The loss is :  1.320881
# The loss is :  1.320881
# The loss is :  1.3208809
# The loss is :  1.3208807
# The loss is :  1.3208807
# The loss is :  1.3208807
# The loss is :  1.3208805
# The loss is :  1.3208805
# The loss is :  1.3208804
# The loss is :  1.3208805
# The loss is :  1.3208803
# The loss is :  1.3208802
# The loss is :  1.3208802
# The loss is :  1.3208802
# The loss is :  1.32088
# The loss is :  1.32088
# The loss is :  1.32088
# The loss is :  1.3208798
# The loss is :  1.3208799
# The loss is :  1.3208798
# The loss is :  1.3208798
# The loss is :  1.3208798
# The loss is :  1.3208797
# The loss is :  1.3208796
# The loss is :  1.3208795
# The loss is :  1.3208795
# The loss is :  1.3208793
# The loss is :  1.3208793
# The loss is :  1.3208792
# The loss is :  1.3208792
# The loss is :  1.3208792
# The loss is :  1.3208791
# The loss is :  1.320879
# The loss is :  1.320879
# The loss is :  1.3208789
# The loss is :  1.3208789
# The loss is :  1.3208789
# The loss is :  1.3208789
# The loss is :  1.3208785
# The loss is :  1.3208785
# The loss is :  1.3208785
# The loss is :  1.3208785
# The loss is :  1.3208784
# The loss is :  1.3208784
# The loss is :  1.3208784
# The loss is :  1.3208781
# The loss is :  1.3208781
# The loss is :  1.320878
# The loss is :  1.320878
# The loss is :  1.320878
# The loss is :  1.320878
# The loss is :  1.3208778
# The loss is :  1.3208778
# The loss is :  1.3208777
# The loss is :  1.3208777
# The loss is :  1.3208777
# The loss is :  1.3208777
# The loss is :  1.3208776
# The loss is :  1.3208774
# The loss is :  1.3208773
# The loss is :  1.3208773
# The loss is :  1.3208772
# The loss is :  1.3208772
# The loss is :  1.3208772
# The loss is :  1.3208771
# The loss is :  1.3208768
# The loss is :  1.320877
# The loss is :  1.3208767
# The loss is :  1.3208768
# The loss is :  1.3208767
# The loss is :  1.3208767
# The loss is :  1.3208767
# The loss is :  1.3208765
# The loss is :  1.3208765
# The loss is :  1.3208764
# The loss is :  1.3208764
# The loss is :  1.3208764
# The loss is :  1.3208762
# The loss is :  1.3208762
# The loss is :  1.3208761
# The loss is :  1.3208761
# The loss is :  1.320876
# The loss is :  1.320876
# The loss is :  1.320876
# The loss is :  1.320876
# The loss is :  1.3208759
# The loss is :  1.3208758
# The loss is :  1.3208756
# The loss is :  1.3208755
# The loss is :  1.3208756
# The loss is :  1.3208755
# The loss is :  1.3208755
# The loss is :  1.3208754
# The loss is :  1.3208754
# The loss is :  1.3208753
# The loss is :  1.3208752
# The loss is :  1.3208752
# The loss is :  1.320875
# The loss is :  1.3208749
# The loss is :  1.320875
# The loss is :  1.3208748
# The loss is :  1.3208747
# The loss is :  1.3208747
# The loss is :  1.3208747
# The loss is :  1.3208746
# The loss is :  1.3208746
# The loss is :  1.3208745
# The loss is :  1.3208745
# The loss is :  1.3208743
# The loss is :  1.3208742
# The loss is :  1.3208742
# The loss is :  1.3208742
# The loss is :  1.3208742
# The loss is :  1.3208741
# The loss is :  1.320874
# The loss is :  1.320874
# The loss is :  1.320874
# The loss is :  1.320874
# The loss is :  1.3208737
# The loss is :  1.3208737
# The loss is :  1.3208737
# The loss is :  1.3208736
# The loss is :  1.3208736
# The loss is :  1.3208736
# The loss is :  1.3208734
# The loss is :  1.3208734
# The loss is :  1.3208734
# The loss is :  1.3208734
# The loss is :  1.3208731
# The loss is :  1.320873
# The loss is :  1.320873
# The loss is :  1.320873
# The loss is :  1.320873
# The loss is :  1.320873
# The loss is :  1.3208728
# The loss is :  1.3208727
# The loss is :  1.3208727
# The loss is :  1.3208727
# The loss is :  1.3208724
# The loss is :  1.3208725
# The loss is :  1.3208724
# The loss is :  1.3208724
# The loss is :  1.3208724
# The loss is :  1.3208723
# The loss is :  1.3208722
# The loss is :  1.3208722
# The loss is :  1.3208722
# The loss is :  1.3208722
# The loss is :  1.3208722
# The loss is :  1.320872
# The loss is :  1.3208718
# The loss is :  1.3208718
# The loss is :  1.3208718
# The loss is :  1.3208718
# The loss is :  1.3208717
# The loss is :  1.3208717
# The loss is :  1.3208716
# The loss is :  1.3208714
# The loss is :  1.3208714
# The loss is :  1.3208714
# The loss is :  1.3208714
# The loss is :  1.3208712
# The loss is :  1.3208712
# The loss is :  1.3208711
# The loss is :  1.320871
# The loss is :  1.320871
# The loss is :  1.3208709
# The loss is :  1.3208709
# The loss is :  1.3208709
# The loss is :  1.3208709
# The loss is :  1.3208706
# The loss is :  1.3208705
# The loss is :  1.3208705
# The loss is :  1.3208705
# The loss is :  1.3208704
# The loss is :  1.3208704
# The loss is :  1.3208704
# The loss is :  1.3208704
# The loss is :  1.3208703
# The loss is :  1.3208702
# The loss is :  1.32087
# The loss is :  1.32087
# The loss is :  1.3208702
# The loss is :  1.32087
# The loss is :  1.32087
# The loss is :  1.3208699
# The loss is :  1.3208697
# The loss is :  1.3208697
# The loss is :  1.3208696
# The loss is :  1.3208696
# The loss is :  1.3208694
# The loss is :  1.3208694
# The loss is :  1.3208694
# The loss is :  1.3208693
# The loss is :  1.3208692
# The loss is :  1.3208692
# The loss is :  1.3208692
# The loss is :  1.3208691
# The loss is :  1.3208691
# The loss is :  1.3208691
# The loss is :  1.3208688
# The loss is :  1.3208687
# The loss is :  1.3208687
# The loss is :  1.3208687
# The loss is :  1.3208687
# The loss is :  1.3208687
# The loss is :  1.3208685
# The loss is :  1.3208685
# The loss is :  1.3208685
# The loss is :  1.3208685
# The loss is :  1.3208684
# The loss is :  1.3208684
# The loss is :  1.3208683
# The loss is :  1.3208683
# The loss is :  1.3208681
# The loss is :  1.3208681
# The loss is :  1.320868
# The loss is :  1.3208679
# The loss is :  1.3208679
# The loss is :  1.3208679
# The loss is :  1.3208679
# The loss is :  1.3208677
# The loss is :  1.3208677
# The loss is :  1.3208675
# The loss is :  1.3208675
# The loss is :  1.3208675
# The loss is :  1.3208674
# The loss is :  1.3208673
# The loss is :  1.3208673
# The loss is :  1.3208672
# The loss is :  1.3208672
# The loss is :  1.3208672
# The loss is :  1.3208671
# The loss is :  1.320867
# The loss is :  1.320867
# The loss is :  1.320867
# The loss is :  1.3208668
# The loss is :  1.3208668
# The loss is :  1.3208666
# The loss is :  1.3208666
# The loss is :  1.3208666
# The loss is :  1.3208666
# The loss is :  1.3208666
# The loss is :  1.3208665
# The loss is :  1.3208663
# The loss is :  1.3208662
# The loss is :  1.3208662
# The loss is :  1.3208662
# The loss is :  1.3208662
# The loss is :  1.3208661
# The loss is :  1.3208661
# The loss is :  1.3208659
# The loss is :  1.3208659
# The loss is :  1.3208659
# The loss is :  1.3208659
# The loss is :  1.3208658
# The loss is :  1.3208658
# The loss is :  1.3208656
# The loss is :  1.3208655
# The loss is :  1.3208654
# The loss is :  1.3208654
# The loss is :  1.3208654
# The loss is :  1.3208653
# The loss is :  1.3208653
# The loss is :  1.3208653
# The loss is :  1.320865
# The loss is :  1.320865
# The loss is :  1.320865
# The loss is :  1.3208649
# The loss is :  1.3208648
# The loss is :  1.3208648
# The loss is :  1.3208648
# The loss is :  1.3208648
# The loss is :  1.3208647
# The loss is :  1.3208646
# The loss is :  1.3208646
# The loss is :  1.3208646
# The loss is :  1.3208646
# The loss is :  1.3208644
# The loss is :  1.3208644
# The loss is :  1.3208643
# The loss is :  1.3208642
# The loss is :  1.3208642
# The loss is :  1.3208641
# The loss is :  1.3208641
# The loss is :  1.3208641
# The loss is :  1.320864
# The loss is :  1.3208638
# The loss is :  1.3208638
# The loss is :  1.3208638
# The loss is :  1.3208636
# The loss is :  1.3208636
# The loss is :  1.3208636
# The loss is :  1.3208636
# The loss is :  1.3208636
# The loss is :  1.3208635
# The loss is :  1.3208632
# The loss is :  1.3208632
# The loss is :  1.3208632
# The loss is :  1.3208632
# The loss is :  1.3208632
# The loss is :  1.3208631
# The loss is :  1.3208629
# The loss is :  1.3208629
# The loss is :  1.3208629
# The loss is :  1.3208629
# The loss is :  1.3208628
# The loss is :  1.3208628
# The loss is :  1.3208628
# The loss is :  1.3208628
# The loss is :  1.3208627
# The loss is :  1.3208625
# The loss is :  1.3208624
# The loss is :  1.3208624
# The loss is :  1.3208624
# The loss is :  1.3208623
# The loss is :  1.3208622
# The loss is :  1.320862
# The loss is :  1.320862
# The loss is :  1.320862
# The loss is :  1.3208619
# The loss is :  1.3208619
# The loss is :  1.3208619
# The loss is :  1.3208618
# The loss is :  1.3208617
# The loss is :  1.3208617
# The loss is :  1.3208617
# The loss is :  1.3208616
# The loss is :  1.3208615
# The loss is :  1.3208615
# The loss is :  1.3208615
# The loss is :  1.3208615
# The loss is :  1.3208612
# The loss is :  1.3208611
# The loss is :  1.3208611
# The loss is :  1.3208611
# The loss is :  1.3208611
# The loss is :  1.320861
# The loss is :  1.320861
# The loss is :  1.3208609
# The loss is :  1.3208609
# The loss is :  1.3208609
# The loss is :  1.3208607
# The loss is :  1.3208607
# The loss is :  1.3208609
# The loss is :  1.3208606
# The loss is :  1.3208606
# The loss is :  1.3208605
# The loss is :  1.3208603
# The loss is :  1.3208604
# The loss is :  1.3208604
# The loss is :  1.3208603
# The loss is :  1.3208603
# The loss is :  1.3208603
# The loss is :  1.32086
# The loss is :  1.3208599
# The loss is :  1.3208599
# The loss is :  1.3208598
# The loss is :  1.3208598
# The loss is :  1.3208598
# The loss is :  1.3208598
# The loss is :  1.3208597
# The loss is :  1.3208596
# The loss is :  1.3208594
# The loss is :  1.3208594
# The loss is :  1.3208594
# The loss is :  1.3208593
# The loss is :  1.3208593
# The loss is :  1.3208593
# The loss is :  1.3208592
# The loss is :  1.3208591
# The loss is :  1.320859
# The loss is :  1.320859
# The loss is :  1.320859
# The loss is :  1.320859
# The loss is :  1.320859
# The loss is :  1.320859
# The loss is :  1.3208588
# The loss is :  1.3208587
# The loss is :  1.3208587
# The loss is :  1.3208587
# The loss is :  1.3208585
# The loss is :  1.3208585
# The loss is :  1.3208585
# The loss is :  1.3208584
# The loss is :  1.3208584
# The loss is :  1.3208581
# The loss is :  1.3208582
# The loss is :  1.3208582
# The loss is :  1.3208581
# The loss is :  1.3208581
# The loss is :  1.320858
# The loss is :  1.3208579
# The loss is :  1.3208579
# The loss is :  1.3208578
# The loss is :  1.3208576
# The loss is :  1.3208576
# The loss is :  1.3208576
# The loss is :  1.3208576
# The loss is :  1.3208574
# The loss is :  1.3208574
# The loss is :  1.3208573
# The loss is :  1.3208573
# The loss is :  1.3208573
# The loss is :  1.3208572
# The loss is :  1.3208572
# The loss is :  1.3208572
# The loss is :  1.320857
# The loss is :  1.320857
# The loss is :  1.3208569
# The loss is :  1.3208569
# The loss is :  1.3208569
# The loss is :  1.3208569
# The loss is :  1.3208568
# The loss is :  1.3208567
# The loss is :  1.3208566
# The loss is :  1.3208566
# The loss is :  1.3208566
# The loss is :  1.3208566
# The loss is :  1.3208565
# The loss is :  1.3208563
# The loss is :  1.3208563
# The loss is :  1.3208562
# The loss is :  1.3208562
# The loss is :  1.3208562
# The loss is :  1.3208561
# The loss is :  1.320856
# The loss is :  1.320856
# The loss is :  1.320856
# The loss is :  1.3208559
# The loss is :  1.3208557
# The loss is :  1.3208556
# The loss is :  1.3208556
# The loss is :  1.3208555
# The loss is :  1.3208555
# The loss is :  1.3208555
# The loss is :  1.3208555
# The loss is :  1.3208555
# The loss is :  1.3208553
# The loss is :  1.3208551
# The loss is :  1.3208553
# The loss is :  1.3208551
# The loss is :  1.3208551
# The loss is :  1.3208551
# The loss is :  1.3208551
# The loss is :  1.320855
# The loss is :  1.3208549
# The loss is :  1.3208548
# The loss is :  1.3208548
# The loss is :  1.3208548
# The loss is :  1.3208548
# The loss is :  1.3208548
# The loss is :  1.3208547
# The loss is :  1.3208545
# The loss is :  1.3208544
# The loss is :  1.3208544
# The loss is :  1.3208543
# The loss is :  1.3208543
# The loss is :  1.3208543
# The loss is :  1.3208542
# The loss is :  1.3208542
# The loss is :  1.3208541
# The loss is :  1.3208541
# The loss is :  1.320854
# The loss is :  1.3208538
# The loss is :  1.3208538
# The loss is :  1.3208538
# The loss is :  1.3208538
# The loss is :  1.3208537
# The loss is :  1.3208535
# The loss is :  1.3208535
# The loss is :  1.3208535
# The loss is :  1.3208535
# The loss is :  1.3208535
# The loss is :  1.3208532
